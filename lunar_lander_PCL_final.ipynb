# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import gymnasium as gym
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt
import imageio
import os

# Hyperparameters
ENV_NAME = "LunarLander-v3"
EPISODES = 2000
GAMMA = 0.99
TAU = 0.05  # reduced entropy weight
K = 2
LR = 3e-4
MAX_STEPS = 500
REPLAY_SIZE = 10000
BATCH_SIZE = 32
EVAL_INTERVAL = 50
GRAD_CLIP = 0.3
GIF_SAVE_PATH = "D:/Coding Projects/Reinforcement Learning/lander_demo_final.gif"


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class PolicyNet(nn.Module):
    def __init__(self, state_dim, action_dim):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(state_dim, 128), nn.ReLU(),
            nn.Linear(128, 128), nn.ReLU(),
            nn.Linear(128, action_dim)
        )

    def forward(self, x):
        logits = self.model(x)
        log_probs = F.log_softmax(logits, dim=-1)
        probs = F.softmax(logits, dim=-1)
        return log_probs, probs

class ValueNet(nn.Module):
    def __init__(self, state_dim):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(state_dim, 128), nn.ReLU(),
            nn.Linear(128, 128), nn.ReLU(),
            nn.Linear(128, 1)
        )

    def forward(self, x):
        return self.model(x).squeeze(-1)

class TrajectoryReplayBuffer:
    def __init__(self, max_size):
        self.buffer = deque(maxlen=max_size)

    def push(self, trajectory):
        self.buffer.append(trajectory)

    def sample(self, batch_size, k):
        samples = []
        for _ in range(batch_size):
            traj = random.choice(self.buffer)
            if len(traj) > k:
                t = random.randint(0, len(traj) - k - 1)
                samples.append(traj[t:t + k + 1])
        return samples

    def __len__(self):
        return len(self.buffer)

def collect_trajectory(env, policy_net):
    traj = []
    obs, _ = env.reset()
    for _ in range(MAX_STEPS):
        obs_tensor = torch.FloatTensor(obs).unsqueeze(0).to(device)
        log_probs, probs = policy_net(obs_tensor)
        dist = torch.distributions.Categorical(probs)
        action = dist.sample().item()

        next_obs, reward, terminated, truncated, _ = env.step(action)
        traj.append((obs, action, reward, next_obs))

        if terminated or truncated:
            break
        obs = next_obs
    return traj

def evaluate_policy(env, policy_net, episodes=5):
    policy_net.eval()
    total_reward = 0
    for _ in range(episodes):
        obs, _ = env.reset()
        done = False
        episode_reward = 0
        while not done:
            obs_tensor = torch.FloatTensor(obs).unsqueeze(0).to(device)
            _, probs = policy_net(obs_tensor)
            action = torch.argmax(probs, dim=1).item()
            obs, reward, terminated, truncated, _ = env.step(action)
            episode_reward += reward
            done = terminated or truncated
        total_reward += episode_reward
    avg_reward = total_reward / episodes
    print(f"[Eval] Avg Reward over {episodes} episodes: {avg_reward:.2f}")
    policy_net.train()

def generate_gif(policy_net):
    env = gym.make(ENV_NAME, render_mode="rgb_array")
    obs, _ = env.reset()
    frames = []
    for _ in range(MAX_STEPS):
        frame = env.render()
        frames.append(frame)
        obs_tensor = torch.FloatTensor(obs).unsqueeze(0).to(device)
        with torch.no_grad():
            _, probs = policy_net(obs_tensor)
        action = torch.argmax(probs, dim=1).item()
        obs, _, terminated, truncated, _ = env.step(action)
        if terminated or truncated:
            break
    env.close()
    imageio.mimsave(GIF_SAVE_PATH, frames, duration=1/30)
    print(f"✅ GIF saved as '{GIF_SAVE_PATH}'")

def plot_metrics(reward_history, loss_history):
    min_len = min(len(reward_history), len(loss_history))
    reward_history = reward_history[:min_len]
    loss_history = loss_history[:min_len]
    episodes = np.arange(min_len)
    ma50 = np.convolve(reward_history, np.ones(50)/50, mode='valid')

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(episodes, reward_history, label="Reward")
    plt.plot(np.arange(49, len(ma50)+49), ma50, label="MA(50)")
    plt.xlabel("Episode")
    plt.ylabel("Reward")
    plt.legend()
    plt.title("Episode Rewards")

    plt.subplot(1, 2, 2)
    plt.plot(episodes, loss_history, label="Loss")
    plt.xlabel("Episode")
    plt.ylabel("Loss")
    plt.title("Loss Curve")
    plt.legend()

    plt.tight_layout()
    plt.savefig("training_metrics.png")
    print("📈 Training plot saved as 'training_metrics.png'")
    plt.show()

def train():
    env = gym.make(ENV_NAME)
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.n

    policy_net = PolicyNet(state_dim, action_dim).to(device)
    value_net = ValueNet(state_dim).to(device)

    optimizer = optim.AdamW(list(policy_net.parameters()) + list(value_net.parameters()), lr=LR, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.97)
    buffer = TrajectoryReplayBuffer(REPLAY_SIZE)
    reward_history = []
    loss_history = []

    for episode in range(EPISODES):
        entropy_coeff = max(0.01, TAU * (0.995 ** episode))
        traj = collect_trajectory(env, policy_net)
        buffer.push(traj)
        episode_reward = sum([step[2] for step in traj])
        reward_history.append(episode_reward)

        if len(buffer) < BATCH_SIZE:
            continue

        batch = buffer.sample(BATCH_SIZE, K)
        total_loss = 0

        for path in batch:
            R, log_pi_sum = 0, 0
            for i in range(K):
                s_i, a_i, r_i, _ = path[i]
                R += (GAMMA ** i) * r_i
                s_i_tensor = torch.FloatTensor(s_i).unsqueeze(0).to(device)
                log_probs, _ = policy_net(s_i_tensor)
                clipped_log_prob = torch.clamp(log_probs[0, a_i], min=-20, max=0)
                log_pi_sum += clipped_log_prob

            s_t = torch.FloatTensor(path[0][0]).unsqueeze(0).to(device)
            s_tk = torch.FloatTensor(path[K][0]).unsqueeze(0).to(device)
            V_s_t = value_net(s_t)
            V_s_tk = torch.clamp(value_net(s_tk).detach(), min=-500, max=500)

            delta = R + (GAMMA ** K) * V_s_tk - V_s_t - entropy_coeff * log_pi_sum
            delta = torch.clamp(delta, min=-20, max=20)
            loss = delta.pow(2).mean()

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(list(policy_net.parameters()) + list(value_net.parameters()), GRAD_CLIP)
            optimizer.step()
            total_loss += loss.item()

        loss_history.append(total_loss)
        scheduler.step()
        avg_reward = sum(reward_history[-50:]) / min(len(reward_history), 50)
        print(f"Ep {episode:03d} | Loss: {total_loss:.2f} | Reward: {episode_reward:.2f} | MA(50): {avg_reward:.2f}")

        if episode % 10 == 0:
            print(f"[Track] Last10 Reward Avg: {np.mean(reward_history[-10:]):.2f}")
        if episode % EVAL_INTERVAL == 0:
            evaluate_policy(env, policy_net)

    torch.save(policy_net.state_dict(), "pcl_policy_lunarlander.pt")
    torch.save(value_net.state_dict(), "pcl_value_lunarlander.pt")
    print("✅ Models saved as 'pcl_policy_lunarlander.pt' and 'pcl_value_lunarlander.pt'")
    env.close()

    if any(np.mean(reward_history[i:i+10]) > 200 for i in range(len(reward_history) - 10)):
        print("🎉 Problem Solved: Agent consistently lands the Lunar Lander!")
    else:
        print("⚠️ Not yet solved: Keep training or tune hyperparameters.")

    generate_gif(policy_net)
    plot_metrics(reward_history, loss_history)

if __name__ == "__main__":
    train()
# Out:
# Ep 031 | Loss: 471.68 | Reward: -261.58 | MA(50): -167.80
# Ep 032 | Loss: 828.07 | Reward: -100.64 | MA(50): -165.76
# Ep 033 | Loss: 455.01 | Reward: -144.18 | MA(50): -165.13
# Ep 034 | Loss: 402.08 | Reward: -99.14 | MA(50): -163.24
# Ep 035 | Loss: 779.72 | Reward: -354.91 | MA(50): -168.56
# Ep 036 | Loss: 515.51 | Reward: -309.71 | MA(50): -172.38
# Ep 037 | Loss: 966.04 | Reward: -330.70 | MA(50): -176.55
# Ep 038 | Loss: 764.31 | Reward: -304.31 | MA(50): -179.82
# Ep 039 | Loss: 623.99 | Reward: -126.20 | MA(50): -178.48
# Ep 040 | Loss: 697.74 | Reward: -623.06 | MA(50): -189.32
# [Track] Last10 Reward Avg: -265.44
# Ep 041 | Loss: 1065.12 | Reward: -882.64 | MA(50): -205.83
# Ep 042 | Loss: 951.21 | Reward: -663.00 | MA(50): -216.46
# Ep 043 | Loss: 1004.63 | Reward: -909.52 | MA(50): -232.22
# Ep 044 | Loss: 582.84 | Reward: -862.96 | MA(50): -246.23
# Ep 045 | Loss: 1974.12 | Reward: -593.41 | MA(50): -253.78
# Ep 046 | Loss: 1185.75 | Reward: -601.31 | MA(50): -261.17
# Ep 047 | Loss: 844.10 | Reward: -1074.37 | MA(50): -278.11
# Ep 048 | Loss: 1362.54 | Reward: -404.21 | MA(50): -280.69
# Ep 049 | Loss: 2106.66 | Reward: -716.93 | MA(50): -289.41
# Ep 050 | Loss: 2146.29 | Reward: -535.33 | MA(50): -297.45
# [Track] Last10 Reward Avg: -724.37
# [Eval] Avg Reward over 5 episodes: -947.30
# Ep 051 | Loss: 2052.30 | Reward: -601.43 | MA(50): -307.61
# Ep 052 | Loss: 1578.87 | Reward: -3118.49 | MA(50): -367.74
# Ep 053 | Loss: 2195.72 | Reward: -561.15 | MA(50): -373.47
# Ep 054 | Loss: 1137.77 | Reward: -617.06 | MA(50): -382.37
# Ep 055 | Loss: 2698.59 | Reward: -702.48 | MA(50): -393.56
# Ep 056 | Loss: 1468.74 | Reward: -470.13 | MA(50): -395.90
# Ep 057 | Loss: 1419.37 | Reward: -523.25 | MA(50): -398.77
# Ep 058 | Loss: 2392.42 | Reward: -605.16 | MA(50): -404.70
# Ep 059 | Loss: 2779.48 | Reward: -623.16 | MA(50): -413.49
# Ep 060 | Loss: 2326.41 | Reward: -719.52 | MA(50): -423.02
# [Track] Last10 Reward Avg: -854.18
# Ep 061 | Loss: 2564.16 | Reward: -592.54 | MA(50): -433.27
# Ep 062 | Loss: 1193.26 | Reward: -995.83 | MA(50): -446.19
# Ep 063 | Loss: 1401.32 | Reward: -1828.79 | MA(50): -480.09
# Ep 064 | Loss: 2204.40 | Reward: -759.54 | MA(50): -495.50
# Ep 065 | Loss: 3088.78 | Reward: -3653.54 | MA(50): -564.06
# Ep 066 | Loss: 1919.56 | Reward: -397.88 | MA(50): -570.84
# Ep 067 | Loss: 2745.86 | Reward: -530.93 | MA(50): -579.41
# Ep 068 | Loss: 2331.29 | Reward: -3822.94 | MA(50): -654.20
# Ep 069 | Loss: 2985.19 | Reward: -893.55 | MA(50): -667.93
# Ep 070 | Loss: 2480.36 | Reward: -589.30 | MA(50): -676.69
# [Track] Last10 Reward Avg: -1406.48
# Ep 071 | Loss: 2962.55 | Reward: -2248.61 | MA(50): -718.86
# Ep 072 | Loss: 2646.06 | Reward: -1022.12 | MA(50): -738.30
# Ep 073 | Loss: 3438.87 | Reward: -481.19 | MA(50): -742.99
# Ep 074 | Loss: 1772.51 | Reward: -916.75 | MA(50): -759.53
# Ep 075 | Loss: 3393.21 | Reward: -844.87 | MA(50): -774.48
# Ep 076 | Loss: 2804.70 | Reward: -828.44 | MA(50): -784.86
# Ep 077 | Loss: 2804.82 | Reward: -548.35 | MA(50): -792.95
# Ep 078 | Loss: 3906.00 | Reward: -736.87 | MA(50): -806.45
# Ep 079 | Loss: 2878.64 | Reward: -559.83 | MA(50): -814.93
# Ep 080 | Loss: 3324.27 | Reward: -1030.05 | MA(50): -834.44
# [Track] Last10 Reward Avg: -921.71
# Ep 081 | Loss: 3810.51 | Reward: -475.55 | MA(50): -838.72
# Ep 082 | Loss: 2888.70 | Reward: -779.22 | MA(50): -852.29
# Ep 083 | Loss: 2978.89 | Reward: -919.29 | MA(50): -867.79
# Ep 084 | Loss: 2634.90 | Reward: -695.42 | MA(50): -879.72
# Ep 085 | Loss: 3732.77 | Reward: -429.64 | MA(50): -881.21
# Ep 086 | Loss: 2016.93 | Reward: -974.85 | MA(50): -894.51
# Ep 087 | Loss: 3143.84 | Reward: -2162.41 | MA(50): -931.15
# Ep 088 | Loss: 3181.06 | Reward: -616.21 | MA(50): -937.39
# Ep 089 | Loss: 2927.31 | Reward: -780.30 | MA(50): -950.47
# Ep 090 | Loss: 3713.29 | Reward: -677.28 | MA(50): -951.55
# [Track] Last10 Reward Avg: -851.02
# Ep 091 | Loss: 3204.52 | Reward: -2053.30 | MA(50): -974.97
# Ep 092 | Loss: 2774.61 | Reward: -570.54 | MA(50): -973.12
# Ep 093 | Loss: 2736.85 | Reward: -810.65 | MA(50): -971.14
# Ep 094 | Loss: 4262.77 | Reward: -1115.15 | MA(50): -976.18
# Ep 095 | Loss: 3603.57 | Reward: -1259.25 | MA(50): -989.50
# Ep 096 | Loss: 2772.53 | Reward: -1167.22 | MA(50): -1000.82
# Ep 097 | Loss: 3917.70 | Reward: -1598.78 | MA(50): -1011.31
# Ep 098 | Loss: 3698.37 | Reward: -510.36 | MA(50): -1013.43
# Ep 099 | Loss: 4743.33 | Reward: -457.53 | MA(50): -1008.24
# Ep 100 | Loss: 4563.85 | Reward: -1936.99 | MA(50): -1036.27
# [Track] Last10 Reward Avg: -1147.98
# [Eval] Avg Reward over 5 episodes: -850.32
# Ep 101 | Loss: 4126.79 | Reward: -502.45 | MA(50): -1034.29
# Ep 102 | Loss: 4318.70 | Reward: -406.75 | MA(50): -980.06
# Ep 103 | Loss: 4986.66 | Reward: -687.68 | MA(50): -982.59
# Ep 104 | Loss: 3859.68 | Reward: -373.87 | MA(50): -977.73
# Ep 105 | Loss: 4476.72 | Reward: -517.03 | MA(50): -974.02
# Ep 106 | Loss: 5068.47 | Reward: -415.66 | MA(50): -972.93
# Ep 107 | Loss: 4110.86 | Reward: -302.83 | MA(50): -968.52
# Ep 108 | Loss: 4621.20 | Reward: -118.52 | MA(50): -958.79
# Ep 109 | Loss: 3286.74 | Reward: -295.13 | MA(50): -952.23
# Ep 110 | Loss: 5335.91 | Reward: -370.67 | MA(50): -945.25
# [Track] Last10 Reward Avg: -399.06
# Ep 111 | Loss: 6365.58 | Reward: -218.27 | MA(50): -937.76
# Ep 112 | Loss: 4908.84 | Reward: -448.03 | MA(50): -926.81
# Ep 113 | Loss: 5838.47 | Reward: -257.09 | MA(50): -895.37
# Ep 114 | Loss: 4334.55 | Reward: -131.95 | MA(50): -882.82
# Ep 115 | Loss: 4742.86 | Reward: -546.77 | MA(50): -820.69
# Ep 116 | Loss: 5998.90 | Reward: -388.30 | MA(50): -820.50
# Ep 117 | Loss: 4748.08 | Reward: -336.72 | MA(50): -816.61
# Ep 118 | Loss: 4421.62 | Reward: -433.03 | MA(50): -748.81
# Ep 119 | Loss: 4318.43 | Reward: -494.88 | MA(50): -740.84
# Ep 120 | Loss: 4515.83 | Reward: -334.29 | MA(50): -735.74
# [Track] Last10 Reward Avg: -358.93
# Ep 121 | Loss: 5027.17 | Reward: -378.95 | MA(50): -698.35
# Ep 122 | Loss: 2771.84 | Reward: -326.55 | MA(50): -684.43
# Ep 123 | Loss: 5464.08 | Reward: -318.85 | MA(50): -681.19
# Ep 124 | Loss: 4794.78 | Reward: -232.10 | MA(50): -667.49
# Ep 125 | Loss: 5365.53 | Reward: -117.43 | MA(50): -652.95
# Ep 126 | Loss: 5374.58 | Reward: -485.92 | MA(50): -646.10
# Ep 127 | Loss: 4601.78 | Reward: -133.90 | MA(50): -637.81
# Ep 128 | Loss: 4746.92 | Reward: -135.98 | MA(50): -625.79
# Ep 129 | Loss: 4864.97 | Reward: -125.01 | MA(50): -617.09
# Ep 130 | Loss: 6819.08 | Reward: -102.25 | MA(50): -598.54
# [Track] Last10 Reward Avg: -235.69
# Ep 131 | Loss: 7022.01 | Reward: -133.57 | MA(50): -591.70
# Ep 132 | Loss: 5049.60 | Reward: -131.96 | MA(50): -578.75
# Ep 133 | Loss: 3916.93 | Reward: -106.89 | MA(50): -562.50
# Ep 134 | Loss: 4696.91 | Reward: -85.86 | MA(50): -550.31
# Ep 135 | Loss: 5742.37 | Reward: -132.95 | MA(50): -544.38
# Ep 136 | Loss: 4265.11 | Reward: -117.93 | MA(50): -527.24
# Ep 137 | Loss: 6071.38 | Reward: -167.82 | MA(50): -487.35
# Ep 138 | Loss: 6448.31 | Reward: -158.95 | MA(50): -478.20
# Ep 139 | Loss: 6355.07 | Reward: -99.46 | MA(50): -464.59
# Ep 140 | Loss: 3429.18 | Reward: -168.12 | MA(50): -454.40
# [Track] Last10 Reward Avg: -130.35
# Ep 141 | Loss: 4465.55 | Reward: -259.64 | MA(50): -418.53
# Ep 142 | Loss: 6572.85 | Reward: -415.40 | MA(50): -415.43
# Ep 143 | Loss: 3686.25 | Reward: -138.00 | MA(50): -401.97
# Ep 144 | Loss: 5024.99 | Reward: -147.86 | MA(50): -382.63
# Ep 145 | Loss: 4314.71 | Reward: -121.51 | MA(50): -359.87
# Ep 146 | Loss: 4531.77 | Reward: -135.91 | MA(50): -339.25
# Ep 147 | Loss: 4570.66 | Reward: -169.54 | MA(50): -310.66
# Ep 148 | Loss: 6490.61 | Reward: -190.33 | MA(50): -304.26
# Ep 149 | Loss: 6034.91 | Reward: -154.91 | MA(50): -298.21
# Ep 150 | Loss: 3883.83 | Reward: -141.15 | MA(50): -262.29
# [Track] Last10 Reward Avg: -187.43
# [Eval] Avg Reward over 5 episodes: -436.11
# Ep 151 | Loss: 5194.22 | Reward: -117.04 | MA(50): -254.58
# Ep 152 | Loss: 4571.86 | Reward: -253.13 | MA(50): -251.51
# Ep 153 | Loss: 5090.52 | Reward: -299.74 | MA(50): -243.75
# Ep 154 | Loss: 6284.15 | Reward: -415.60 | MA(50): -244.59
# Ep 155 | Loss: 5106.80 | Reward: -342.11 | MA(50): -241.09
# Ep 156 | Loss: 6776.30 | Reward: -624.21 | MA(50): -245.26
# Ep 157 | Loss: 5045.16 | Reward: -492.36 | MA(50): -249.05
# Ep 158 | Loss: 5854.27 | Reward: -592.85 | MA(50): -258.54
# Ep 159 | Loss: 7395.66 | Reward: -365.47 | MA(50): -259.94
# Ep 160 | Loss: 5407.56 | Reward: -592.48 | MA(50): -264.38
# [Track] Last10 Reward Avg: -409.50
# Ep 161 | Loss: 5142.00 | Reward: -479.17 | MA(50): -269.60
# Ep 162 | Loss: 5313.22 | Reward: -600.47 | MA(50): -272.65
# Ep 163 | Loss: 6450.69 | Reward: -605.68 | MA(50): -279.62
# Ep 164 | Loss: 6714.07 | Reward: -378.76 | MA(50): -284.56
# Ep 165 | Loss: 5174.95 | Reward: -651.78 | MA(50): -286.66
# Ep 166 | Loss: 7042.33 | Reward: -450.45 | MA(50): -287.90
# Ep 167 | Loss: 5776.17 | Reward: -719.41 | MA(50): -295.55
# Ep 168 | Loss: 4189.00 | Reward: -614.16 | MA(50): -299.18
# Ep 169 | Loss: 4941.27 | Reward: -734.48 | MA(50): -303.97
# Ep 170 | Loss: 3703.31 | Reward: -591.55 | MA(50): -309.11
# [Track] Last10 Reward Avg: -582.59
# Ep 171 | Loss: 5741.69 | Reward: -520.24 | MA(50): -311.94
# Ep 172 | Loss: 7699.46 | Reward: -627.80 | MA(50): -317.96
# Ep 173 | Loss: 6609.89 | Reward: -634.37 | MA(50): -324.27
# Ep 174 | Loss: 4855.34 | Reward: -456.96 | MA(50): -328.77
# Ep 175 | Loss: 4335.63 | Reward: -612.63 | MA(50): -338.68
# Ep 176 | Loss: 5095.73 | Reward: -512.36 | MA(50): -339.20
# Ep 177 | Loss: 4748.41 | Reward: -389.25 | MA(50): -344.31
# Ep 178 | Loss: 6455.89 | Reward: -426.95 | MA(50): -350.13
# Ep 179 | Loss: 5313.51 | Reward: -347.23 | MA(50): -354.57
# Ep 180 | Loss: 7159.59 | Reward: -115.96 | MA(50): -354.85
# [Track] Last10 Reward Avg: -464.38
# Ep 181 | Loss: 6126.07 | Reward: -40.88 | MA(50): -353.00
# Ep 182 | Loss: 7455.74 | Reward: 29.95 | MA(50): -349.76
# Ep 183 | Loss: 5183.13 | Reward: -93.31 | MA(50): -349.49
# Ep 184 | Loss: 4769.04 | Reward: -87.60 | MA(50): -349.52
# Ep 185 | Loss: 5000.85 | Reward: -549.07 | MA(50): -357.84
# Ep 186 | Loss: 6565.08 | Reward: -6.79 | MA(50): -355.62
# Ep 187 | Loss: 5790.76 | Reward: -65.53 | MA(50): -353.57
# Ep 188 | Loss: 6906.66 | Reward: -169.39 | MA(50): -353.78
# Ep 189 | Loss: 5466.05 | Reward: -394.20 | MA(50): -359.68
# Ep 190 | Loss: 7790.15 | Reward: -40.98 | MA(50): -357.13
# [Track] Last10 Reward Avg: -141.78
# Ep 191 | Loss: 8165.35 | Reward: -314.83 | MA(50): -358.24
# Ep 192 | Loss: 5772.44 | Reward: -270.49 | MA(50): -355.34
# Ep 193 | Loss: 7836.58 | Reward: -292.54 | MA(50): -358.43
# Ep 194 | Loss: 6686.32 | Reward: -414.22 | MA(50): -363.76
# Ep 195 | Loss: 5113.13 | Reward: -490.14 | MA(50): -371.13
# Ep 196 | Loss: 5887.47 | Reward: -569.11 | MA(50): -379.79
# Ep 197 | Loss: 7073.75 | Reward: -365.07 | MA(50): -383.70
# Ep 198 | Loss: 4967.42 | Reward: -504.05 | MA(50): -389.98
# Ep 199 | Loss: 5150.19 | Reward: -515.30 | MA(50): -397.19
# Ep 200 | Loss: 6550.44 | Reward: 139.14 | MA(50): -391.58
# [Track] Last10 Reward Avg: -359.66
# [Eval] Avg Reward over 5 episodes: -292.34
# Ep 201 | Loss: 6332.81 | Reward: -371.88 | MA(50): -396.68
# Ep 202 | Loss: 5202.96 | Reward: -564.56 | MA(50): -402.91
# Ep 203 | Loss: 7568.86 | Reward: -295.18 | MA(50): -402.82
# Ep 204 | Loss: 5986.71 | Reward: -579.84 | MA(50): -406.10
# Ep 205 | Loss: 5962.27 | Reward: -481.71 | MA(50): -408.89
# Ep 206 | Loss: 6535.08 | Reward: -402.33 | MA(50): -404.45
# Ep 207 | Loss: 5293.12 | Reward: -512.48 | MA(50): -404.86
# Ep 208 | Loss: 4584.84 | Reward: -325.16 | MA(50): -399.50
# Ep 209 | Loss: 7567.17 | Reward: -493.60 | MA(50): -402.06
# Ep 210 | Loss: 6313.71 | Reward: -626.05 | MA(50): -402.74
# [Track] Last10 Reward Avg: -465.28
# Ep 211 | Loss: 6194.66 | Reward: -579.65 | MA(50): -404.75
# Ep 212 | Loss: 4644.76 | Reward: -590.84 | MA(50): -404.55
# Ep 213 | Loss: 4591.61 | Reward: -233.44 | MA(50): -397.11
# Ep 214 | Loss: 5753.44 | Reward: 6.17 | MA(50): -389.41
# Ep 215 | Loss: 6961.90 | Reward: -372.24 | MA(50): -383.82
# Ep 216 | Loss: 5930.48 | Reward: -327.60 | MA(50): -381.36
# Ep 217 | Loss: 5921.24 | Reward: -578.26 | MA(50): -378.54
# Ep 218 | Loss: 5524.33 | Reward: -529.78 | MA(50): -376.85
# Ep 219 | Loss: 7581.02 | Reward: -718.14 | MA(50): -376.52
# Ep 220 | Loss: 7322.89 | Reward: -376.50 | MA(50): -372.22
# [Track] Last10 Reward Avg: -430.03
# Ep 221 | Loss: 7783.06 | Reward: -209.86 | MA(50): -366.02
# Ep 222 | Loss: 6321.93 | Reward: -245.31 | MA(50): -358.37
# Ep 223 | Loss: 5211.49 | Reward: -427.55 | MA(50): -354.23
# Ep 224 | Loss: 8460.09 | Reward: -586.28 | MA(50): -356.82
# Ep 225 | Loss: 6522.75 | Reward: -360.00 | MA(50): -351.76
# Ep 226 | Loss: 8407.10 | Reward: -598.12 | MA(50): -353.48
# Ep 227 | Loss: 5506.51 | Reward: -176.73 | MA(50): -349.23
# Ep 228 | Loss: 7519.67 | Reward: -471.84 | MA(50): -350.13
# Ep 229 | Loss: 8493.67 | Reward: -110.99 | MA(50): -345.40
# Ep 230 | Loss: 6892.31 | Reward: -480.91 | MA(50): -352.70
# [Track] Last10 Reward Avg: -366.76
# Ep 231 | Loss: 7958.00 | Reward: -461.57 | MA(50): -361.11
# Ep 232 | Loss: 5834.78 | Reward: -408.82 | MA(50): -369.89
# Ep 233 | Loss: 7233.74 | Reward: -340.57 | MA(50): -374.83
# Ep 234 | Loss: 7916.84 | Reward: -163.85 | MA(50): -376.36
# Ep 235 | Loss: 7486.84 | Reward: -380.47 | MA(50): -372.99
# Ep 236 | Loss: 7252.69 | Reward: -74.21 | MA(50): -374.34
# Ep 237 | Loss: 6892.76 | Reward: -491.51 | MA(50): -382.86
# Ep 238 | Loss: 6988.54 | Reward: -132.00 | MA(50): -382.11
# Ep 239 | Loss: 5726.70 | Reward: -147.60 | MA(50): -377.18
# Ep 240 | Loss: 7194.23 | Reward: -43.67 | MA(50): -377.23
# [Track] Last10 Reward Avg: -264.43
# Ep 241 | Loss: 7997.98 | Reward: -390.71 | MA(50): -378.75
# Ep 242 | Loss: 7684.50 | Reward: -274.21 | MA(50): -378.82
# Ep 243 | Loss: 7603.74 | Reward: -490.11 | MA(50): -382.77
# Ep 244 | Loss: 7677.58 | Reward: -383.70 | MA(50): -382.16
# Ep 245 | Loss: 7622.14 | Reward: -522.60 | MA(50): -382.81
# Ep 246 | Loss: 7905.09 | Reward: -573.38 | MA(50): -382.90
# Ep 247 | Loss: 6502.81 | Reward: -568.60 | MA(50): -386.97
# Ep 248 | Loss: 7382.93 | Reward: -542.38 | MA(50): -387.73
# Ep 249 | Loss: 8906.70 | Reward: -241.55 | MA(50): -382.26
# Ep 250 | Loss: 6925.28 | Reward: -75.98 | MA(50): -386.56
# [Track] Last10 Reward Avg: -406.32
# [Eval] Avg Reward over 5 episodes: -212.47
# Ep 251 | Loss: 6926.55 | Reward: -229.88 | MA(50): -383.72
# Ep 252 | Loss: 9821.09 | Reward: -321.51 | MA(50): -378.86
# Ep 253 | Loss: 4229.85 | Reward: -546.39 | MA(50): -383.89
# Ep 254 | Loss: 4300.15 | Reward: -265.26 | MA(50): -377.59
# Ep 255 | Loss: 6249.56 | Reward: 46.12 | MA(50): -367.04
# Ep 256 | Loss: 8306.05 | Reward: -266.63 | MA(50): -364.32
# Ep 257 | Loss: 8461.63 | Reward: -274.90 | MA(50): -359.57
# Ep 258 | Loss: 5723.47 | Reward: -270.84 | MA(50): -358.49
# Ep 259 | Loss: 6379.77 | Reward: -214.12 | MA(50): -352.90
# Ep 260 | Loss: 5214.97 | Reward: -390.98 | MA(50): -348.20
# [Track] Last10 Reward Avg: -273.44
# Ep 261 | Loss: 7858.68 | Reward: -101.98 | MA(50): -338.64
# Ep 262 | Loss: 7914.92 | Reward: -113.99 | MA(50): -329.10
# Ep 263 | Loss: 7498.86 | Reward: -256.02 | MA(50): -329.56
# Ep 264 | Loss: 7019.70 | Reward: -89.68 | MA(50): -331.47
# Ep 265 | Loss: 8062.85 | Reward: -262.13 | MA(50): -329.27
# Ep 266 | Loss: 6441.43 | Reward: -71.65 | MA(50): -324.15
# Ep 267 | Loss: 8032.61 | Reward: 14.81 | MA(50): -312.29
# Ep 268 | Loss: 8163.77 | Reward: -154.83 | MA(50): -304.79
# Ep 269 | Loss: 7867.81 | Reward: -223.22 | MA(50): -294.89
# Ep 270 | Loss: 6829.03 | Reward: 12.15 | MA(50): -287.12
# [Track] Last10 Reward Avg: -124.65
# Ep 271 | Loss: 7091.13 | Reward: -96.44 | MA(50): -284.85
# Ep 272 | Loss: 8202.79 | Reward: -211.82 | MA(50): -284.18
# Ep 273 | Loss: 7864.45 | Reward: 27.43 | MA(50): -275.08
# Ep 274 | Loss: 8736.71 | Reward: -227.75 | MA(50): -267.91
# Ep 275 | Loss: 8849.40 | Reward: -80.70 | MA(50): -262.33
# Ep 276 | Loss: 6064.24 | Reward: -59.84 | MA(50): -251.56
# Ep 277 | Loss: 5899.33 | Reward: -284.73 | MA(50): -253.72
# Ep 278 | Loss: 7408.36 | Reward: -99.12 | MA(50): -246.27
# Ep 279 | Loss: 6959.03 | Reward: -36.65 | MA(50): -244.78
# Ep 280 | Loss: 7945.98 | Reward: 6.20 | MA(50): -235.04
# [Track] Last10 Reward Avg: -106.34
# Ep 281 | Loss: 8011.09 | Reward: -25.44 | MA(50): -226.31
# Ep 282 | Loss: 5947.61 | Reward: -195.49 | MA(50): -222.05
# Ep 283 | Loss: 9234.25 | Reward: -24.71 | MA(50): -215.73
# Ep 284 | Loss: 8685.22 | Reward: 9.23 | MA(50): -212.27
# Ep 285 | Loss: 5382.24 | Reward: -76.95 | MA(50): -206.20
# Ep 286 | Loss: 7146.68 | Reward: -67.41 | MA(50): -206.06
# Ep 287 | Loss: 7110.77 | Reward: 10.56 | MA(50): -196.02
# Ep 288 | Loss: 7765.17 | Reward: 10.58 | MA(50): -193.17
# Ep 289 | Loss: 7933.91 | Reward: -26.06 | MA(50): -190.74
# Ep 290 | Loss: 7468.50 | Reward: -13.16 | MA(50): -190.13
# [Track] Last10 Reward Avg: -39.89
# Ep 291 | Loss: 6831.92 | Reward: -113.59 | MA(50): -184.59
# Ep 292 | Loss: 7129.98 | Reward: -78.94 | MA(50): -180.68
# Ep 293 | Loss: 7688.57 | Reward: -212.03 | MA(50): -175.12
# Ep 294 | Loss: 7625.33 | Reward: -214.38 | MA(50): -171.73
# Ep 295 | Loss: 6308.53 | Reward: -64.08 | MA(50): -162.56
# Ep 296 | Loss: 8909.99 | Reward: -104.42 | MA(50): -153.18
# Ep 297 | Loss: 5668.03 | Reward: -47.90 | MA(50): -142.77
# Ep 298 | Loss: 5792.70 | Reward: -41.26 | MA(50): -132.75
# Ep 299 | Loss: 7035.03 | Reward: -65.60 | MA(50): -129.23
# Ep 300 | Loss: 7908.31 | Reward: 10.03 | MA(50): -127.51
# [Track] Last10 Reward Avg: -93.22
# [Eval] Avg Reward over 5 episodes: -20.19
# Ep 301 | Loss: 8281.49 | Reward: -160.44 | MA(50): -126.12
# Ep 302 | Loss: 8126.68 | Reward: -136.92 | MA(50): -122.43
# Ep 303 | Loss: 9501.88 | Reward: 17.45 | MA(50): -111.15
# Ep 304 | Loss: 6825.06 | Reward: -13.66 | MA(50): -106.12
# Ep 305 | Loss: 8777.84 | Reward: -30.35 | MA(50): -107.65
# Ep 306 | Loss: 7469.11 | Reward: -238.35 | MA(50): -107.08
# Ep 307 | Loss: 7242.60 | Reward: 25.16 | MA(50): -101.08
# Ep 308 | Loss: 7209.91 | Reward: -191.51 | MA(50): -99.49
# Ep 309 | Loss: 6881.32 | Reward: -25.13 | MA(50): -95.71
# Ep 310 | Loss: 7917.54 | Reward: 13.47 | MA(50): -87.63
# [Track] Last10 Reward Avg: -74.03
# Ep 311 | Loss: 7666.35 | Reward: -173.31 | MA(50): -89.05
# Ep 312 | Loss: 7329.70 | Reward: -241.42 | MA(50): -91.60
# Ep 313 | Loss: 7412.35 | Reward: -37.69 | MA(50): -87.23
# Ep 314 | Loss: 8570.71 | Reward: -17.45 | MA(50): -85.79
# Ep 315 | Loss: 8524.51 | Reward: -65.92 | MA(50): -81.87
# Ep 316 | Loss: 7923.46 | Reward: -17.09 | MA(50): -80.77
# Ep 317 | Loss: 8376.81 | Reward: 17.27 | MA(50): -80.72
# Ep 318 | Loss: 8701.28 | Reward: 24.60 | MA(50): -77.14
# Ep 319 | Loss: 6991.90 | Reward: -26.24 | MA(50): -73.20
# Ep 320 | Loss: 9199.11 | Reward: 21.64 | MA(50): -73.01
# [Track] Last10 Reward Avg: -51.56
# Ep 321 | Loss: 8615.76 | Reward: -55.21 | MA(50): -72.18
# Ep 322 | Loss: 6694.53 | Reward: -119.94 | MA(50): -70.34
# Ep 323 | Loss: 8557.97 | Reward: -17.88 | MA(50): -71.25
# Ep 324 | Loss: 6700.56 | Reward: -30.46 | MA(50): -67.31
# Ep 325 | Loss: 7887.36 | Reward: -67.51 | MA(50): -67.04
# Ep 326 | Loss: 7839.82 | Reward: -50.84 | MA(50): -66.86
# Ep 327 | Loss: 8592.05 | Reward: -49.76 | MA(50): -62.16
# Ep 328 | Loss: 6980.30 | Reward: -78.66 | MA(50): -61.75
# Ep 329 | Loss: 7198.53 | Reward: -31.04 | MA(50): -61.64
# Ep 330 | Loss: 7193.39 | Reward: -32.69 | MA(50): -62.42
# [Track] Last10 Reward Avg: -53.40
# Ep 331 | Loss: 9084.55 | Reward: -45.89 | MA(50): -62.83
# Ep 332 | Loss: 7281.15 | Reward: -64.70 | MA(50): -60.21
# Ep 333 | Loss: 8476.14 | Reward: -37.81 | MA(50): -60.47
# Ep 334 | Loss: 7180.92 | Reward: -36.76 | MA(50): -61.39
# Ep 335 | Loss: 9183.91 | Reward: -47.62 | MA(50): -60.81
# Ep 336 | Loss: 7275.77 | Reward: -132.14 | MA(50): -62.10
# Ep 337 | Loss: 8789.23 | Reward: 45.24 | MA(50): -61.41
# Ep 338 | Loss: 7263.62 | Reward: -38.20 | MA(50): -62.38
# Ep 339 | Loss: 6956.73 | Reward: -2.16 | MA(50): -61.91
# Ep 340 | Loss: 7877.70 | Reward: 6.64 | MA(50): -61.51
# [Track] Last10 Reward Avg: -35.34
# Ep 341 | Loss: 7747.77 | Reward: 10.08 | MA(50): -59.04
# Ep 342 | Loss: 6891.34 | Reward: -7.63 | MA(50): -57.61
# Ep 343 | Loss: 6906.48 | Reward: 3.31 | MA(50): -53.30
# Ep 344 | Loss: 7947.87 | Reward: 14.22 | MA(50): -48.73
# Ep 345 | Loss: 7687.32 | Reward: -45.39 | MA(50): -48.36
# Ep 346 | Loss: 6036.45 | Reward: 6.41 | MA(50): -46.14
# Ep 347 | Loss: 6652.54 | Reward: 15.58 | MA(50): -44.87
# Ep 348 | Loss: 6754.05 | Reward: -258.44 | MA(50): -49.21
# Ep 349 | Loss: 6871.03 | Reward: -44.02 | MA(50): -48.78
# Ep 350 | Loss: 6692.63 | Reward: 18.86 | MA(50): -48.61
# [Track] Last10 Reward Avg: -28.70
# [Eval] Avg Reward over 5 episodes: -43.14
# Ep 351 | Loss: 6926.33 | Reward: -46.29 | MA(50): -46.32
# Ep 352 | Loss: 8666.42 | Reward: -187.27 | MA(50): -47.33
# Ep 353 | Loss: 7525.65 | Reward: 23.11 | MA(50): -47.22
# Ep 354 | Loss: 6476.40 | Reward: -116.59 | MA(50): -49.28
# Ep 355 | Loss: 8628.39 | Reward: -86.93 | MA(50): -50.41
# Ep 356 | Loss: 8471.05 | Reward: -66.81 | MA(50): -46.98
# Ep 357 | Loss: 7912.16 | Reward: -8.57 | MA(50): -47.65
# Ep 358 | Loss: 7519.96 | Reward: -112.36 | MA(50): -46.07
# Ep 359 | Loss: 7764.93 | Reward: -320.94 | MA(50): -51.98
# Ep 360 | Loss: 7493.86 | Reward: -6.59 | MA(50): -52.39
# [Track] Last10 Reward Avg: -92.92
# Ep 361 | Loss: 6773.87 | Reward: -67.94 | MA(50): -50.28
# Ep 362 | Loss: 7592.23 | Reward: -252.59 | MA(50): -50.50
# Ep 363 | Loss: 9593.74 | Reward: -118.41 | MA(50): -52.12
# Ep 364 | Loss: 9168.91 | Reward: 5.31 | MA(50): -51.66
# Ep 365 | Loss: 8516.18 | Reward: -25.15 | MA(50): -50.85
# Ep 366 | Loss: 7641.00 | Reward: -122.05 | MA(50): -52.94
# Ep 367 | Loss: 7651.11 | Reward: -78.46 | MA(50): -54.86
# Ep 368 | Loss: 8404.15 | Reward: -178.82 | MA(50): -58.93
# Ep 369 | Loss: 7485.84 | Reward: -155.49 | MA(50): -61.51
# Ep 370 | Loss: 7310.27 | Reward: -114.35 | MA(50): -64.23
# [Track] Last10 Reward Avg: -110.80
# Ep 371 | Loss: 7576.49 | Reward: -42.72 | MA(50): -63.98
# Ep 372 | Loss: 8476.58 | Reward: -486.76 | MA(50): -71.32
# Ep 373 | Loss: 8720.45 | Reward: -188.12 | MA(50): -74.72
# Ep 374 | Loss: 6558.87 | Reward: -89.33 | MA(50): -75.90
# Ep 375 | Loss: 6530.30 | Reward: -44.31 | MA(50): -75.44
# Ep 376 | Loss: 6028.11 | Reward: -64.96 | MA(50): -75.72
# Ep 377 | Loss: 8484.87 | Reward: -59.52 | MA(50): -75.91
# Ep 378 | Loss: 7302.41 | Reward: -250.09 | MA(50): -79.34
# Ep 379 | Loss: 6350.74 | Reward: -127.76 | MA(50): -81.28
# Ep 380 | Loss: 7682.84 | Reward: -53.09 | MA(50): -81.69
# [Track] Last10 Reward Avg: -140.67
# Ep 381 | Loss: 8468.98 | Reward: -222.31 | MA(50): -85.21
# Ep 382 | Loss: 6833.99 | Reward: -126.97 | MA(50): -86.46
# Ep 383 | Loss: 7168.90 | Reward: -229.82 | MA(50): -90.30
# Ep 384 | Loss: 6929.23 | Reward: -65.57 | MA(50): -90.88
# Ep 385 | Loss: 8889.04 | Reward: -280.91 | MA(50): -95.54
# Ep 386 | Loss: 7445.57 | Reward: -27.55 | MA(50): -93.45
# Ep 387 | Loss: 7030.00 | Reward: -99.52 | MA(50): -96.34
# Ep 388 | Loss: 7380.71 | Reward: -133.60 | MA(50): -98.25
# Ep 389 | Loss: 9056.58 | Reward: -423.09 | MA(50): -106.67
# Ep 390 | Loss: 8745.79 | Reward: -68.38 | MA(50): -108.17
# [Track] Last10 Reward Avg: -167.77
# Ep 391 | Loss: 8653.99 | Reward: -53.44 | MA(50): -109.44
# Ep 392 | Loss: 7870.00 | Reward: -106.50 | MA(50): -111.42
# Ep 393 | Loss: 8263.28 | Reward: -72.69 | MA(50): -112.94
# Ep 394 | Loss: 7141.52 | Reward: -185.73 | MA(50): -116.94
# Ep 395 | Loss: 7804.54 | Reward: -116.30 | MA(50): -118.36
# Ep 396 | Loss: 7195.06 | Reward: -141.17 | MA(50): -121.31
# Ep 397 | Loss: 7843.45 | Reward: -138.66 | MA(50): -124.39
# Ep 398 | Loss: 6597.81 | Reward: -168.33 | MA(50): -122.59
# Ep 399 | Loss: 7979.69 | Reward: -76.19 | MA(50): -123.23
# Ep 400 | Loss: 8106.25 | Reward: -195.75 | MA(50): -127.53
# [Track] Last10 Reward Avg: -125.47
# [Eval] Avg Reward over 5 episodes: -132.55
# Ep 401 | Loss: 8417.27 | Reward: -154.54 | MA(50): -129.69
# Ep 402 | Loss: 8217.80 | Reward: -139.20 | MA(50): -128.73
# Ep 403 | Loss: 7819.44 | Reward: -127.82 | MA(50): -131.75
# Ep 404 | Loss: 6795.92 | Reward: -120.28 | MA(50): -131.82
# Ep 405 | Loss: 7117.79 | Reward: -222.38 | MA(50): -134.53
# Ep 406 | Loss: 7972.40 | Reward: -491.18 | MA(50): -143.02
# Ep 407 | Loss: 8386.38 | Reward: -76.06 | MA(50): -144.37
# Ep 408 | Loss: 8375.73 | Reward: -74.34 | MA(50): -143.61
# Ep 409 | Loss: 6497.86 | Reward: -68.06 | MA(50): -138.55
# Ep 410 | Loss: 7713.03 | Reward: -200.06 | MA(50): -142.42
# [Track] Last10 Reward Avg: -167.39
# Ep 411 | Loss: 8807.07 | Reward: -61.80 | MA(50): -142.30
# Ep 412 | Loss: 7100.79 | Reward: -52.03 | MA(50): -138.29
# Ep 413 | Loss: 8681.24 | Reward: -100.13 | MA(50): -137.92
# Ep 414 | Loss: 7914.61 | Reward: -75.21 | MA(50): -139.53
# Ep 415 | Loss: 7850.60 | Reward: -167.08 | MA(50): -142.37
# Ep 416 | Loss: 8173.83 | Reward: -57.96 | MA(50): -141.09
# Ep 417 | Loss: 8373.63 | Reward: -58.58 | MA(50): -140.69
# Ep 418 | Loss: 8792.48 | Reward: -75.36 | MA(50): -138.62
# Ep 419 | Loss: 6971.96 | Reward: -65.03 | MA(50): -136.81
# Ep 420 | Loss: 9211.92 | Reward: -289.52 | MA(50): -140.31
# [Track] Last10 Reward Avg: -100.27
# Ep 421 | Loss: 8204.68 | Reward: -24.62 | MA(50): -139.95
# Ep 422 | Loss: 10584.47 | Reward: -83.92 | MA(50): -131.90
# Ep 423 | Loss: 8043.47 | Reward: -94.90 | MA(50): -130.03
# Ep 424 | Loss: 9064.31 | Reward: -94.01 | MA(50): -130.12
# Ep 425 | Loss: 6319.25 | Reward: 14.14 | MA(50): -128.96
# Ep 426 | Loss: 8216.07 | Reward: -46.71 | MA(50): -128.59
# Ep 427 | Loss: 7828.81 | Reward: -11.89 | MA(50): -127.64
# Ep 428 | Loss: 7979.62 | Reward: 5.59 | MA(50): -122.52
# Ep 429 | Loss: 8155.37 | Reward: -47.56 | MA(50): -120.92
# Ep 430 | Loss: 6985.06 | Reward: -47.57 | MA(50): -120.81
# [Track] Last10 Reward Avg: -43.14
# Ep 431 | Loss: 6207.76 | Reward: -4.03 | MA(50): -116.44
# Ep 432 | Loss: 7633.51 | Reward: -31.67 | MA(50): -114.54
# Ep 433 | Loss: 9055.44 | Reward: 18.94 | MA(50): -109.56
# Ep 434 | Loss: 6570.25 | Reward: -38.61 | MA(50): -109.02
# Ep 435 | Loss: 7807.41 | Reward: -8.53 | MA(50): -103.58
# Ep 436 | Loss: 7630.48 | Reward: 0.33 | MA(50): -103.02
# Ep 437 | Loss: 7270.00 | Reward: -3.37 | MA(50): -101.10
# Ep 438 | Loss: 7195.85 | Reward: 11.30 | MA(50): -98.20
# Ep 439 | Loss: 7758.70 | Reward: 19.72 | MA(50): -89.34
# Ep 440 | Loss: 6795.94 | Reward: 23.43 | MA(50): -87.51
# [Track] Last10 Reward Avg: -1.25
# Ep 441 | Loss: 6931.89 | Reward: 138.30 | MA(50): -83.67
# Ep 442 | Loss: 7508.41 | Reward: -9.52 | MA(50): -81.73
# Ep 443 | Loss: 8841.16 | Reward: -27.34 | MA(50): -80.82
# Ep 444 | Loss: 6877.95 | Reward: -21.71 | MA(50): -77.54
# Ep 445 | Loss: 7224.32 | Reward: -25.42 | MA(50): -75.73
# Ep 446 | Loss: 7661.37 | Reward: -5.20 | MA(50): -73.01
# Ep 447 | Loss: 7653.63 | Reward: 10.26 | MA(50): -70.03
# Ep 448 | Loss: 8517.09 | Reward: 12.89 | MA(50): -66.40
# Ep 449 | Loss: 7537.41 | Reward: -3.90 | MA(50): -64.96
# Ep 450 | Loss: 8862.12 | Reward: 39.42 | MA(50): -60.25
# [Track] Last10 Reward Avg: 10.78
# [Eval] Avg Reward over 5 episodes: 7.22
# Ep 451 | Loss: 7872.66 | Reward: 8.11 | MA(50): -57.00
# Ep 452 | Loss: 6103.79 | Reward: 8.01 | MA(50): -54.06
# Ep 453 | Loss: 7195.77 | Reward: 25.17 | MA(50): -51.00
# Ep 454 | Loss: 7993.62 | Reward: 20.31 | MA(50): -48.19
# Ep 455 | Loss: 9430.94 | Reward: -36.71 | MA(50): -44.47
# Ep 456 | Loss: 6372.42 | Reward: -35.64 | MA(50): -35.36
# Ep 457 | Loss: 9399.80 | Reward: -110.14 | MA(50): -36.04
# Ep 458 | Loss: 7391.19 | Reward: 27.18 | MA(50): -34.01
# Ep 459 | Loss: 7335.60 | Reward: -17.46 | MA(50): -33.00
# Ep 460 | Loss: 6790.84 | Reward: -38.54 | MA(50): -29.77
# [Track] Last10 Reward Avg: -14.97
# Ep 461 | Loss: 8863.08 | Reward: -1.84 | MA(50): -28.57
# Ep 462 | Loss: 6881.52 | Reward: -32.68 | MA(50): -28.18
# Ep 463 | Loss: 7249.47 | Reward: 98.97 | MA(50): -24.20
# Ep 464 | Loss: 7576.19 | Reward: -7.90 | MA(50): -22.86
# Ep 465 | Loss: 7815.92 | Reward: -32.37 | MA(50): -20.16
# Ep 466 | Loss: 7266.51 | Reward: -28.81 | MA(50): -19.58
# Ep 467 | Loss: 8753.15 | Reward: 42.91 | MA(50): -17.55
# Ep 468 | Loss: 7998.59 | Reward: -10.58 | MA(50): -16.25
# Ep 469 | Loss: 7321.69 | Reward: -39.40 | MA(50): -15.74
# Ep 470 | Loss: 7836.32 | Reward: 29.17 | MA(50): -9.37
# [Track] Last10 Reward Avg: 1.75
# Ep 471 | Loss: 8757.33 | Reward: 13.41 | MA(50): -8.61
# Ep 472 | Loss: 8707.34 | Reward: 8.40 | MA(50): -6.76
# Ep 473 | Loss: 7745.96 | Reward: 23.03 | MA(50): -4.40
# Ep 474 | Loss: 7559.42 | Reward: -36.45 | MA(50): -3.25
# Ep 475 | Loss: 7591.18 | Reward: -25.98 | MA(50): -4.05
# Ep 476 | Loss: 7642.83 | Reward: -32.19 | MA(50): -3.76
# Ep 477 | Loss: 7327.00 | Reward: 45.35 | MA(50): -2.62
# Ep 478 | Loss: 8821.08 | Reward: 24.53 | MA(50): -2.24
# Ep 479 | Loss: 6753.38 | Reward: -25.73 | MA(50): -1.80
# Ep 480 | Loss: 7086.49 | Reward: -7.43 | MA(50): -1.00
# [Track] Last10 Reward Avg: -1.31
# Ep 481 | Loss: 8177.98 | Reward: -9.15 | MA(50): -1.10
# Ep 482 | Loss: 7028.08 | Reward: -23.58 | MA(50): -0.94
# Ep 483 | Loss: 7660.91 | Reward: -30.50 | MA(50): -1.93
# Ep 484 | Loss: 7778.19 | Reward: -86.54 | MA(50): -2.89
# Ep 485 | Loss: 6989.54 | Reward: -59.59 | MA(50): -3.91
# Ep 486 | Loss: 5637.55 | Reward: -56.40 | MA(50): -5.04
# Ep 487 | Loss: 6672.84 | Reward: -82.05 | MA(50): -6.62
# Ep 488 | Loss: 8176.79 | Reward: -53.41 | MA(50): -7.91
# Ep 489 | Loss: 8089.81 | Reward: -39.97 | MA(50): -9.10
# Ep 490 | Loss: 6761.96 | Reward: -59.90 | MA(50): -10.77
# [Track] Last10 Reward Avg: -50.11
# Ep 491 | Loss: 7043.65 | Reward: -50.92 | MA(50): -14.56
# Ep 492 | Loss: 5321.66 | Reward: -62.15 | MA(50): -15.61
# Ep 493 | Loss: 6549.71 | Reward: -79.98 | MA(50): -16.66
# Ep 494 | Loss: 7840.85 | Reward: -86.29 | MA(50): -17.95
# Ep 495 | Loss: 8546.35 | Reward: -47.00 | MA(50): -18.39
# Ep 496 | Loss: 7199.28 | Reward: -33.51 | MA(50): -18.95
# Ep 497 | Loss: 6760.53 | Reward: -18.24 | MA(50): -19.52
# Ep 498 | Loss: 7956.38 | Reward: -58.79 | MA(50): -20.95
# Ep 499 | Loss: 5721.20 | Reward: -62.02 | MA(50): -22.12
# Ep 500 | Loss: 6198.44 | Reward: -75.50 | MA(50): -24.42
# [Track] Last10 Reward Avg: -57.44
# [Eval] Avg Reward over 5 episodes: -57.16
# Ep 501 | Loss: 6860.02 | Reward: -130.39 | MA(50): -27.19
# Ep 502 | Loss: 5542.18 | Reward: -10.00 | MA(50): -27.55
# Ep 503 | Loss: 7326.01 | Reward: -93.49 | MA(50): -29.92
# Ep 504 | Loss: 7375.35 | Reward: -41.74 | MA(50): -31.16
# Ep 505 | Loss: 6793.41 | Reward: -63.17 | MA(50): -31.69
# Ep 506 | Loss: 6084.20 | Reward: -44.24 | MA(50): -31.86
# Ep 507 | Loss: 7422.10 | Reward: -24.29 | MA(50): -30.14
# Ep 508 | Loss: 6614.50 | Reward: -113.03 | MA(50): -32.95
# Ep 509 | Loss: 6355.67 | Reward: -42.22 | MA(50): -33.44
# Ep 510 | Loss: 9250.88 | Reward: -28.08 | MA(50): -33.23
# [Track] Last10 Reward Avg: -59.06
# Ep 511 | Loss: 6798.01 | Reward: -4.76 | MA(50): -33.29
# Ep 512 | Loss: 4288.60 | Reward: -35.59 | MA(50): -33.35
# Ep 513 | Loss: 8622.20 | Reward: 62.25 | MA(50): -34.09
# Ep 514 | Loss: 7958.19 | Reward: -51.45 | MA(50): -34.96
# Ep 515 | Loss: 7089.82 | Reward: -53.84 | MA(50): -35.39
# Ep 516 | Loss: 6626.22 | Reward: -55.23 | MA(50): -35.91
# Ep 517 | Loss: 8154.57 | Reward: -51.73 | MA(50): -37.81
# Ep 518 | Loss: 6141.12 | Reward: -112.61 | MA(50): -39.85
# Ep 519 | Loss: 7067.84 | Reward: -50.61 | MA(50): -40.07
# Ep 520 | Loss: 8238.67 | Reward: -61.13 | MA(50): -41.88
# [Track] Last10 Reward Avg: -41.47
# Ep 521 | Loss: 6993.43 | Reward: -59.04 | MA(50): -43.33
# Ep 522 | Loss: 7639.61 | Reward: 13.22 | MA(50): -43.23
# Ep 523 | Loss: 6927.33 | Reward: 10.41 | MA(50): -43.48
# Ep 524 | Loss: 7930.06 | Reward: -55.33 | MA(50): -43.86
# Ep 525 | Loss: 7740.47 | Reward: -65.40 | MA(50): -44.65
# Ep 526 | Loss: 6098.42 | Reward: -9.18 | MA(50): -44.19
# Ep 527 | Loss: 6919.80 | Reward: -10.43 | MA(50): -45.30
# Ep 528 | Loss: 6449.87 | Reward: -18.16 | MA(50): -46.16
# Ep 529 | Loss: 6604.73 | Reward: -29.43 | MA(50): -46.23
# Ep 530 | Loss: 8159.27 | Reward: -50.02 | MA(50): -47.08
# [Track] Last10 Reward Avg: -27.34
# Ep 531 | Loss: 7435.00 | Reward: -20.99 | MA(50): -47.32
# Ep 532 | Loss: 7073.30 | Reward: -57.92 | MA(50): -48.01
# Ep 533 | Loss: 6040.40 | Reward: 27.34 | MA(50): -46.85
# Ep 534 | Loss: 5801.10 | Reward: -146.17 | MA(50): -48.04
# Ep 535 | Loss: 6367.16 | Reward: 28.34 | MA(50): -46.29
# Ep 536 | Loss: 6731.41 | Reward: -70.47 | MA(50): -46.57
# Ep 537 | Loss: 7963.76 | Reward: -60.74 | MA(50): -46.14
# Ep 538 | Loss: 5660.94 | Reward: -49.18 | MA(50): -46.06
# Ep 539 | Loss: 7401.91 | Reward: -70.54 | MA(50): -46.67
# Ep 540 | Loss: 5953.01 | Reward: -62.52 | MA(50): -46.72
# [Track] Last10 Reward Avg: -48.29
# Ep 541 | Loss: 5998.39 | Reward: -89.98 | MA(50): -47.50
# Ep 542 | Loss: 5303.92 | Reward: 24.30 | MA(50): -45.77
# Ep 543 | Loss: 4761.60 | Reward: -62.13 | MA(50): -45.41
# Ep 544 | Loss: 6712.95 | Reward: 30.33 | MA(50): -43.08
# Ep 545 | Loss: 6397.96 | Reward: -46.11 | MA(50): -43.06
# Ep 546 | Loss: 6450.61 | Reward: 28.19 | MA(50): -41.83
# Ep 547 | Loss: 6207.27 | Reward: -50.70 | MA(50): -42.48
# Ep 548 | Loss: 5805.44 | Reward: -31.90 | MA(50): -41.94
# Ep 549 | Loss: 6549.45 | Reward: -56.50 | MA(50): -41.83
# Ep 550 | Loss: 5880.84 | Reward: -103.53 | MA(50): -42.39
# [Track] Last10 Reward Avg: -35.80
# [Eval] Avg Reward over 5 episodes: -53.19
# Ep 551 | Loss: 8045.29 | Reward: -63.35 | MA(50): -41.05
# Ep 552 | Loss: 8195.34 | Reward: -79.46 | MA(50): -42.44
# Ep 553 | Loss: 8178.70 | Reward: -80.93 | MA(50): -42.19
# Ep 554 | Loss: 7424.87 | Reward: -18.29 | MA(50): -41.72
# Ep 555 | Loss: 6709.24 | Reward: -98.76 | MA(50): -42.43
# Ep 556 | Loss: 6471.06 | Reward: -193.66 | MA(50): -45.42
# Ep 557 | Loss: 5063.65 | Reward: -108.74 | MA(50): -47.11
# Ep 558 | Loss: 5738.88 | Reward: -99.41 | MA(50): -46.84
# Ep 559 | Loss: 6968.68 | Reward: -148.56 | MA(50): -48.96
# Ep 560 | Loss: 6338.46 | Reward: -17.78 | MA(50): -48.76
# [Track] Last10 Reward Avg: -90.90
# Ep 561 | Loss: 7763.44 | Reward: -98.63 | MA(50): -50.64
# Ep 562 | Loss: 8403.19 | Reward: 6.82 | MA(50): -49.79
# Ep 563 | Loss: 6379.48 | Reward: -79.29 | MA(50): -52.62
# Ep 564 | Loss: 8200.13 | Reward: -9.94 | MA(50): -51.79
# Ep 565 | Loss: 5589.48 | Reward: -99.92 | MA(50): -52.71
# Ep 566 | Loss: 5819.53 | Reward: -132.36 | MA(50): -54.25
# Ep 567 | Loss: 6101.86 | Reward: 10.71 | MA(50): -53.00
# Ep 568 | Loss: 7069.35 | Reward: 41.85 | MA(50): -49.91
# Ep 569 | Loss: 7686.91 | Reward: -105.82 | MA(50): -51.02
# Ep 570 | Loss: 7378.01 | Reward: 36.31 | MA(50): -49.07
# [Track] Last10 Reward Avg: -43.03
# Ep 571 | Loss: 6073.25 | Reward: -125.43 | MA(50): -50.40
# Ep 572 | Loss: 5950.89 | Reward: -91.71 | MA(50): -52.50
# Ep 573 | Loss: 6774.28 | Reward: -120.35 | MA(50): -55.11
# Ep 574 | Loss: 6634.74 | Reward: -92.54 | MA(50): -55.86
# Ep 575 | Loss: 6299.42 | Reward: -81.64 | MA(50): -56.18
# Ep 576 | Loss: 5740.50 | Reward: -87.91 | MA(50): -57.75
# Ep 577 | Loss: 5103.15 | Reward: -84.28 | MA(50): -59.23
# Ep 578 | Loss: 6866.93 | Reward: -62.89 | MA(50): -60.13
# Ep 579 | Loss: 5895.76 | Reward: 29.30 | MA(50): -58.95
# Ep 580 | Loss: 8006.76 | Reward: -101.98 | MA(50): -59.99
# [Track] Last10 Reward Avg: -81.95
# Ep 581 | Loss: 6523.37 | Reward: -52.41 | MA(50): -60.62
# Ep 582 | Loss: 6768.14 | Reward: -69.28 | MA(50): -60.85
# Ep 583 | Loss: 6743.86 | Reward: -135.92 | MA(50): -64.11
# Ep 584 | Loss: 4831.36 | Reward: 12.12 | MA(50): -60.95
# Ep 585 | Loss: 7097.51 | Reward: -82.46 | MA(50): -63.16
# Ep 586 | Loss: 5905.28 | Reward: -87.51 | MA(50): -63.50
# Ep 587 | Loss: 7058.46 | Reward: -89.77 | MA(50): -64.08
# Ep 588 | Loss: 6082.33 | Reward: -92.00 | MA(50): -64.94
# Ep 589 | Loss: 7481.98 | Reward: 20.96 | MA(50): -63.11
# Ep 590 | Loss: 5843.06 | Reward: -31.44 | MA(50): -62.49
# [Track] Last10 Reward Avg: -60.77
# Ep 591 | Loss: 4495.50 | Reward: -108.63 | MA(50): -62.86
# Ep 592 | Loss: 7333.09 | Reward: -91.52 | MA(50): -65.18
# Ep 593 | Loss: 6517.53 | Reward: -61.61 | MA(50): -65.17
# Ep 594 | Loss: 6581.85 | Reward: 25.40 | MA(50): -65.27
# Ep 595 | Loss: 8204.38 | Reward: -80.29 | MA(50): -65.95
# Ep 596 | Loss: 6070.92 | Reward: -118.57 | MA(50): -68.89
# Ep 597 | Loss: 4577.98 | Reward: -105.61 | MA(50): -69.98
# Ep 598 | Loss: 7249.14 | Reward: -89.00 | MA(50): -71.13
# Ep 599 | Loss: 7470.67 | Reward: 1.87 | MA(50): -69.96
# Ep 600 | Loss: 6224.16 | Reward: -92.42 | MA(50): -69.74
# [Track] Last10 Reward Avg: -72.04
# [Eval] Avg Reward over 5 episodes: -52.33
# Ep 601 | Loss: 6716.72 | Reward: -19.13 | MA(50): -68.85
# Ep 602 | Loss: 7839.08 | Reward: 28.17 | MA(50): -66.70
# Ep 603 | Loss: 5923.65 | Reward: -93.74 | MA(50): -66.95
# Ep 604 | Loss: 5884.36 | Reward: -135.83 | MA(50): -69.31
# Ep 605 | Loss: 8212.20 | Reward: -61.10 | MA(50): -68.55
# Ep 606 | Loss: 6139.01 | Reward: -4.33 | MA(50): -64.77
# Ep 607 | Loss: 6820.20 | Reward: -99.07 | MA(50): -64.57
# Ep 608 | Loss: 5999.68 | Reward: 16.79 | MA(50): -62.25
# Ep 609 | Loss: 6966.49 | Reward: -72.02 | MA(50): -60.72
# Ep 610 | Loss: 6212.79 | Reward: -113.94 | MA(50): -62.64
# [Track] Last10 Reward Avg: -55.42
# Ep 611 | Loss: 5220.10 | Reward: -98.65 | MA(50): -62.64
# Ep 612 | Loss: 4147.20 | Reward: -12.45 | MA(50): -63.03
# Ep 613 | Loss: 6178.22 | Reward: -70.52 | MA(50): -62.85
# Ep 614 | Loss: 6478.67 | Reward: -70.21 | MA(50): -64.06
# Ep 615 | Loss: 3984.51 | Reward: -101.83 | MA(50): -64.09
# Ep 616 | Loss: 6413.25 | Reward: 1.33 | MA(50): -61.42
# Ep 617 | Loss: 6442.95 | Reward: -9.33 | MA(50): -61.82
# Ep 618 | Loss: 7530.81 | Reward: -23.38 | MA(50): -63.13
# Ep 619 | Loss: 6289.96 | Reward: -96.96 | MA(50): -62.95
# Ep 620 | Loss: 4831.91 | Reward: -22.74 | MA(50): -64.13
# [Track] Last10 Reward Avg: -50.47
# Ep 621 | Loss: 6147.38 | Reward: -123.84 | MA(50): -64.10
# Ep 622 | Loss: 6224.46 | Reward: -135.87 | MA(50): -64.98
# Ep 623 | Loss: 5491.16 | Reward: -126.38 | MA(50): -65.10
# Ep 624 | Loss: 7197.59 | Reward: -126.99 | MA(50): -65.79
# Ep 625 | Loss: 6204.42 | Reward: -34.54 | MA(50): -64.85
# Ep 626 | Loss: 7433.89 | Reward: -76.50 | MA(50): -64.62
# Ep 627 | Loss: 7415.93 | Reward: -28.79 | MA(50): -63.51
# Ep 628 | Loss: 7915.48 | Reward: -20.23 | MA(50): -62.66
# Ep 629 | Loss: 8042.93 | Reward: -183.63 | MA(50): -66.92
# Ep 630 | Loss: 6643.15 | Reward: -23.72 | MA(50): -65.35
# [Track] Last10 Reward Avg: -88.05
# Ep 631 | Loss: 6360.19 | Reward: -154.47 | MA(50): -67.39
# Ep 632 | Loss: 5898.69 | Reward: -146.84 | MA(50): -68.94
# Ep 633 | Loss: 7021.46 | Reward: -38.61 | MA(50): -67.00
# Ep 634 | Loss: 4894.60 | Reward: -68.18 | MA(50): -68.60
# Ep 635 | Loss: 7467.00 | Reward: -146.73 | MA(50): -69.89
# Ep 636 | Loss: 5689.14 | Reward: -134.78 | MA(50): -70.83
# Ep 637 | Loss: 4590.02 | Reward: -160.92 | MA(50): -72.26
# Ep 638 | Loss: 6673.71 | Reward: -115.01 | MA(50): -72.72
# Ep 639 | Loss: 4435.11 | Reward: -88.68 | MA(50): -74.91
# Ep 640 | Loss: 6523.51 | Reward: -152.03 | MA(50): -77.32
# [Track] Last10 Reward Avg: -120.63
# Ep 641 | Loss: 6448.60 | Reward: -51.22 | MA(50): -76.17
# Ep 642 | Loss: 6331.56 | Reward: -101.76 | MA(50): -76.38
# Ep 643 | Loss: 7291.05 | Reward: -37.17 | MA(50): -75.89
# Ep 644 | Loss: 5476.57 | Reward: -137.11 | MA(50): -79.14
# Ep 645 | Loss: 6917.64 | Reward: -139.87 | MA(50): -80.33
# Ep 646 | Loss: 7377.66 | Reward: -57.20 | MA(50): -79.10
# Ep 647 | Loss: 6825.46 | Reward: -103.43 | MA(50): -79.06
# Ep 648 | Loss: 5169.11 | Reward: -120.82 | MA(50): -79.70
# Ep 649 | Loss: 5930.64 | Reward: -98.06 | MA(50): -81.70
# Ep 650 | Loss: 6977.33 | Reward: -132.87 | MA(50): -82.50
# [Track] Last10 Reward Avg: -97.95
# [Eval] Avg Reward over 5 episodes: -76.57
# Ep 651 | Loss: 6490.42 | Reward: -82.44 | MA(50): -83.77
# Ep 652 | Loss: 4589.90 | Reward: -51.03 | MA(50): -85.35
# Ep 653 | Loss: 3544.49 | Reward: -122.66 | MA(50): -85.93
# Ep 654 | Loss: 6365.12 | Reward: -43.08 | MA(50): -84.08
# Ep 655 | Loss: 6501.82 | Reward: -120.47 | MA(50): -85.27
# Ep 656 | Loss: 5191.70 | Reward: -14.80 | MA(50): -85.47
# Ep 657 | Loss: 7062.38 | Reward: -29.27 | MA(50): -84.08
# Ep 658 | Loss: 5866.85 | Reward: 12.66 | MA(50): -84.16
# Ep 659 | Loss: 6404.77 | Reward: -143.41 | MA(50): -85.59
# Ep 660 | Loss: 5933.79 | Reward: -22.87 | MA(50): -83.77
# [Track] Last10 Reward Avg: -61.74
# Ep 661 | Loss: 5620.03 | Reward: -125.88 | MA(50): -84.31
# Ep 662 | Loss: 6589.58 | Reward: -70.71 | MA(50): -85.48
# Ep 663 | Loss: 6339.55 | Reward: -12.18 | MA(50): -84.31
# Ep 664 | Loss: 4655.54 | Reward: -135.13 | MA(50): -85.61
# Ep 665 | Loss: 5007.01 | Reward: -135.12 | MA(50): -86.28
# Ep 666 | Loss: 6610.86 | Reward: 1.15 | MA(50): -86.28
# Ep 667 | Loss: 6908.45 | Reward: -42.56 | MA(50): -86.94
# Ep 668 | Loss: 4106.73 | Reward: -79.60 | MA(50): -88.07
# Ep 669 | Loss: 7337.84 | Reward: -20.87 | MA(50): -86.55
# Ep 670 | Loss: 5695.75 | Reward: -137.45 | MA(50): -88.84
# [Track] Last10 Reward Avg: -75.83
# Ep 671 | Loss: 5814.60 | Reward: -82.16 | MA(50): -88.01
# Ep 672 | Loss: 5618.89 | Reward: -135.49 | MA(50): -88.00
# Ep 673 | Loss: 5652.62 | Reward: -2.04 | MA(50): -85.51
# Ep 674 | Loss: 5484.73 | Reward: -32.67 | MA(50): -83.63
# Ep 675 | Loss: 5819.87 | Reward: -153.49 | MA(50): -86.00
# Ep 676 | Loss: 7216.65 | Reward: -87.67 | MA(50): -86.23
# Ep 677 | Loss: 4049.30 | Reward: -208.95 | MA(50): -89.83
# Ep 678 | Loss: 5862.19 | Reward: -111.48 | MA(50): -91.66
# Ep 679 | Loss: 6498.07 | Reward: -215.16 | MA(50): -92.29
# Ep 680 | Loss: 6774.88 | Reward: -56.09 | MA(50): -92.93
# [Track] Last10 Reward Avg: -108.52
# Ep 681 | Loss: 5474.39 | Reward: -223.75 | MA(50): -94.32
# Ep 682 | Loss: 7037.75 | Reward: -96.61 | MA(50): -93.32
# Ep 683 | Loss: 6455.02 | Reward: -182.34 | MA(50): -96.19
# Ep 684 | Loss: 4638.68 | Reward: 4.29 | MA(50): -94.74
# Ep 685 | Loss: 5956.97 | Reward: -148.39 | MA(50): -94.77
# Ep 686 | Loss: 4770.73 | Reward: -139.63 | MA(50): -94.87
# Ep 687 | Loss: 5746.23 | Reward: -35.29 | MA(50): -92.36
# Ep 688 | Loss: 5977.81 | Reward: -150.91 | MA(50): -93.08
# Ep 689 | Loss: 5489.59 | Reward: -26.15 | MA(50): -91.83
# Ep 690 | Loss: 4562.47 | Reward: -110.42 | MA(50): -90.99
# [Track] Last10 Reward Avg: -110.92
# Ep 691 | Loss: 5506.62 | Reward: -168.42 | MA(50): -93.34
# Ep 692 | Loss: 5879.63 | Reward: -148.16 | MA(50): -94.26
# Ep 693 | Loss: 5749.92 | Reward: 2.20 | MA(50): -93.48
# Ep 694 | Loss: 6754.15 | Reward: -52.16 | MA(50): -91.78
# Ep 695 | Loss: 5206.52 | Reward: -89.24 | MA(50): -90.77
# Ep 696 | Loss: 5493.93 | Reward: -234.19 | MA(50): -94.31
# Ep 697 | Loss: 4472.87 | Reward: 33.53 | MA(50): -91.57
# Ep 698 | Loss: 5573.25 | Reward: -196.85 | MA(50): -93.09
# Ep 699 | Loss: 5328.68 | Reward: -192.39 | MA(50): -94.97
# Ep 700 | Loss: 5104.92 | Reward: -5.93 | MA(50): -92.43
# [Track] Last10 Reward Avg: -105.16
# [Eval] Avg Reward over 5 episodes: -151.07
# Ep 701 | Loss: 4750.14 | Reward: -227.15 | MA(50): -95.33
# Ep 702 | Loss: 4167.89 | Reward: -198.47 | MA(50): -98.28
# Ep 703 | Loss: 5226.46 | Reward: -245.36 | MA(50): -100.73
# Ep 704 | Loss: 5389.79 | Reward: -215.99 | MA(50): -104.19
# Ep 705 | Loss: 4813.81 | Reward: -153.60 | MA(50): -104.85
# Ep 706 | Loss: 4255.98 | Reward: -179.30 | MA(50): -108.14
# Ep 707 | Loss: 5522.06 | Reward: -202.26 | MA(50): -111.60
# Ep 708 | Loss: 5311.55 | Reward: -59.47 | MA(50): -113.04
# Ep 709 | Loss: 7342.52 | Reward: -46.25 | MA(50): -111.10
# Ep 710 | Loss: 6569.84 | Reward: -200.29 | MA(50): -114.65
# [Track] Last10 Reward Avg: -172.81
# Ep 711 | Loss: 4978.15 | Reward: -87.15 | MA(50): -113.87
# Ep 712 | Loss: 6369.43 | Reward: -143.91 | MA(50): -115.34
# Ep 713 | Loss: 5478.15 | Reward: -174.74 | MA(50): -118.59
# Ep 714 | Loss: 4996.04 | Reward: -102.70 | MA(50): -117.94
# Ep 715 | Loss: 7245.78 | Reward: -189.98 | MA(50): -119.04
# Ep 716 | Loss: 6083.87 | Reward: -187.99 | MA(50): -122.82
# Ep 717 | Loss: 5506.74 | Reward: -202.46 | MA(50): -126.02
# Ep 718 | Loss: 5384.76 | Reward: -109.51 | MA(50): -126.62
# Ep 719 | Loss: 5391.98 | Reward: -167.95 | MA(50): -129.56
# Ep 720 | Loss: 7341.96 | Reward: -161.34 | MA(50): -130.04
# [Track] Last10 Reward Avg: -152.77
# Ep 721 | Loss: 4615.08 | Reward: -66.84 | MA(50): -129.73
# Ep 722 | Loss: 5532.39 | Reward: -117.90 | MA(50): -129.38
# Ep 723 | Loss: 5538.73 | Reward: -150.37 | MA(50): -132.35
# Ep 724 | Loss: 5081.25 | Reward: -114.62 | MA(50): -133.98
# Ep 725 | Loss: 6024.58 | Reward: -171.51 | MA(50): -134.34
# Ep 726 | Loss: 6937.12 | Reward: -182.97 | MA(50): -136.25
# Ep 727 | Loss: 7821.23 | Reward: -133.25 | MA(50): -134.74
# Ep 728 | Loss: 5070.70 | Reward: -136.15 | MA(50): -135.23
# Ep 729 | Loss: 5360.04 | Reward: 76.29 | MA(50): -129.40
# Ep 730 | Loss: 5325.99 | Reward: -197.24 | MA(50): -132.22
# [Track] Last10 Reward Avg: -119.46
# Ep 731 | Loss: 5602.08 | Reward: -153.76 | MA(50): -130.82
# Ep 732 | Loss: 6764.82 | Reward: -49.30 | MA(50): -129.88
# Ep 733 | Loss: 5858.11 | Reward: -72.88 | MA(50): -127.69
# Ep 734 | Loss: 5795.25 | Reward: 38.21 | MA(50): -127.01
# Ep 735 | Loss: 6650.22 | Reward: -128.28 | MA(50): -126.61
# Ep 736 | Loss: 7251.42 | Reward: -140.48 | MA(50): -126.63
# Ep 737 | Loss: 5131.07 | Reward: -164.45 | MA(50): -129.21
# Ep 738 | Loss: 5806.34 | Reward: -23.59 | MA(50): -126.66
# Ep 739 | Loss: 3447.74 | Reward: 57.71 | MA(50): -124.99
# Ep 740 | Loss: 4628.49 | Reward: -160.82 | MA(50): -125.99
# [Track] Last10 Reward Avg: -79.76
# Ep 741 | Loss: 6458.71 | Reward: -180.85 | MA(50): -126.24
# Ep 742 | Loss: 5938.59 | Reward: -145.20 | MA(50): -126.18
# Ep 743 | Loss: 5765.48 | Reward: 36.41 | MA(50): -125.50
# Ep 744 | Loss: 5487.13 | Reward: -114.64 | MA(50): -126.75
# Ep 745 | Loss: 4158.72 | Reward: -113.93 | MA(50): -127.24
# Ep 746 | Loss: 7300.87 | Reward: -78.19 | MA(50): -124.12
# Ep 747 | Loss: 5809.86 | Reward: -112.00 | MA(50): -127.03
# Ep 748 | Loss: 4428.75 | Reward: -73.75 | MA(50): -124.57
# Ep 749 | Loss: 4369.79 | Reward: 23.01 | MA(50): -120.26
# Ep 750 | Loss: 4833.77 | Reward: -108.30 | MA(50): -122.31
# [Track] Last10 Reward Avg: -86.74
# [Eval] Avg Reward over 5 episodes: 2.09
# Ep 751 | Loss: 7088.96 | Reward: -13.63 | MA(50): -118.04
# Ep 752 | Loss: 7521.08 | Reward: -46.72 | MA(50): -115.00
# Ep 753 | Loss: 5211.68 | Reward: -22.56 | MA(50): -110.55
# Ep 754 | Loss: 3755.06 | Reward: 50.90 | MA(50): -105.21
# Ep 755 | Loss: 6742.51 | Reward: 31.44 | MA(50): -101.51
# Ep 756 | Loss: 5781.81 | Reward: -40.72 | MA(50): -98.74
# Ep 757 | Loss: 7560.20 | Reward: -36.51 | MA(50): -95.42
# Ep 758 | Loss: 4928.59 | Reward: -57.16 | MA(50): -95.38
# Ep 759 | Loss: 5485.48 | Reward: -63.96 | MA(50): -95.73
# Ep 760 | Loss: 5210.44 | Reward: 37.20 | MA(50): -90.98
# [Track] Last10 Reward Avg: -16.17
# Ep 761 | Loss: 5854.10 | Reward: 38.43 | MA(50): -88.47
# Ep 762 | Loss: 4208.26 | Reward: 40.85 | MA(50): -84.78
# Ep 763 | Loss: 5234.81 | Reward: 37.10 | MA(50): -80.54
# Ep 764 | Loss: 6154.67 | Reward: 5.93 | MA(50): -78.37
# Ep 765 | Loss: 5703.97 | Reward: 45.84 | MA(50): -73.65
# Ep 766 | Loss: 7149.59 | Reward: -71.56 | MA(50): -71.32
# Ep 767 | Loss: 4691.72 | Reward: 22.81 | MA(50): -66.82
# Ep 768 | Loss: 5486.82 | Reward: -32.89 | MA(50): -65.28
# Ep 769 | Loss: 6252.05 | Reward: -14.53 | MA(50): -62.21
# Ep 770 | Loss: 5300.68 | Reward: -15.80 | MA(50): -59.30
# [Track] Last10 Reward Avg: 5.62
# Ep 771 | Loss: 6985.56 | Reward: 1.49 | MA(50): -57.94
# Ep 772 | Loss: 4666.89 | Reward: -50.21 | MA(50): -56.58
# Ep 773 | Loss: 3569.33 | Reward: 9.70 | MA(50): -53.38
# Ep 774 | Loss: 4434.80 | Reward: 18.37 | MA(50): -50.72
# Ep 775 | Loss: 4870.10 | Reward: -79.91 | MA(50): -48.89
# Ep 776 | Loss: 6539.20 | Reward: 46.47 | MA(50): -44.30
# Ep 777 | Loss: 4986.38 | Reward: 26.64 | MA(50): -41.10
# Ep 778 | Loss: 6569.51 | Reward: 4.42 | MA(50): -38.29
# Ep 779 | Loss: 5326.93 | Reward: 53.08 | MA(50): -38.76
# Ep 780 | Loss: 7170.00 | Reward: 72.16 | MA(50): -33.37
# [Track] Last10 Reward Avg: 10.22
# Ep 781 | Loss: 5165.65 | Reward: -43.21 | MA(50): -31.16
# Ep 782 | Loss: 4741.84 | Reward: 48.17 | MA(50): -29.21
# Ep 783 | Loss: 5922.71 | Reward: -20.32 | MA(50): -28.16
# Ep 784 | Loss: 7611.93 | Reward: -62.76 | MA(50): -30.18
# Ep 785 | Loss: 3452.59 | Reward: 18.43 | MA(50): -27.24
# Ep 786 | Loss: 5599.89 | Reward: 18.49 | MA(50): -24.06
# Ep 787 | Loss: 6707.15 | Reward: -35.81 | MA(50): -21.49
# Ep 788 | Loss: 4896.76 | Reward: -65.31 | MA(50): -22.32
# Ep 789 | Loss: 4664.55 | Reward: -60.86 | MA(50): -24.70
# Ep 790 | Loss: 5258.31 | Reward: 20.75 | MA(50): -21.06
# [Track] Last10 Reward Avg: -18.24
# Ep 791 | Loss: 5332.55 | Reward: -72.00 | MA(50): -18.89
# Ep 792 | Loss: 5087.58 | Reward: -33.56 | MA(50): -16.65
# Ep 793 | Loss: 5512.08 | Reward: 29.35 | MA(50): -16.80
# Ep 794 | Loss: 5546.45 | Reward: -31.54 | MA(50): -15.13
# Ep 795 | Loss: 4587.14 | Reward: -30.22 | MA(50): -13.46
# Ep 796 | Loss: 5093.87 | Reward: -61.07 | MA(50): -13.12
# Ep 797 | Loss: 5060.14 | Reward: 2.53 | MA(50): -10.83
# Ep 798 | Loss: 6434.32 | Reward: -17.06 | MA(50): -9.69
# Ep 799 | Loss: 4241.99 | Reward: 35.08 | MA(50): -9.45
# Ep 800 | Loss: 4506.69 | Reward: 13.35 | MA(50): -7.02
# [Track] Last10 Reward Avg: -16.52
# [Eval] Avg Reward over 5 episodes: 1.02
# Ep 801 | Loss: 6513.98 | Reward: -5.63 | MA(50): -6.86
# Ep 802 | Loss: 4427.28 | Reward: 15.09 | MA(50): -5.62
# Ep 803 | Loss: 4843.73 | Reward: 32.88 | MA(50): -4.51
# ...
# Ep 1747 | Loss: 1485.30 | Reward: 129.54 | MA(50): 101.36
# Ep 1748 | Loss: 3227.82 | Reward: 111.45 | MA(50): 101.53
# Ep 1749 | Loss: 3128.52 | Reward: 172.04 | MA(50): 105.48
# Ep 1750 | Loss: 3086.63 | Reward: 119.82 | MA(50): 105.88
# [Track] Last10 Reward Avg: 121.69
# [Eval] Avg Reward over 5 episodes: 135.20
# Ep 1751 | Loss: 2287.50 | Reward: 107.19 | MA(50): 105.08
# Ep 1752 | Loss: 3373.94 | Reward: -35.47 | MA(50): 102.39
# Ep 1753 | Loss: 1626.58 | Reward: 164.77 | MA(50): 106.25
# Ep 1754 | Loss: 3025.19 | Reward: 190.31 | MA(50): 105.42
# Ep 1755 | Loss: 2949.35 | Reward: 236.97 | MA(50): 106.23
# Ep 1756 | Loss: 2523.57 | Reward: 75.43 | MA(50): 104.21
# Ep 1757 | Loss: 2973.03 | Reward: 178.02 | MA(50): 108.71
# Ep 1758 | Loss: 2881.64 | Reward: 101.90 | MA(50): 109.14
# Ep 1759 | Loss: 4015.65 | Reward: 167.68 | MA(50): 110.06
# Ep 1760 | Loss: 1575.76 | Reward: 98.17 | MA(50): 112.71
# [Track] Last10 Reward Avg: 128.50
# Ep 1761 | Loss: 4304.79 | Reward: 119.34 | MA(50): 115.78
# Ep 1762 | Loss: 2763.22 | Reward: 64.86 | MA(50): 112.51
# Ep 1763 | Loss: 2375.00 | Reward: 110.13 | MA(50): 111.22
# Ep 1764 | Loss: 1727.59 | Reward: 46.77 | MA(50): 109.31
# Ep 1765 | Loss: 2558.57 | Reward: 169.92 | MA(50): 111.32
# Ep 1766 | Loss: 3208.29 | Reward: 132.62 | MA(50): 111.75
# Ep 1767 | Loss: 2972.12 | Reward: 113.30 | MA(50): 110.47
# Ep 1768 | Loss: 2033.95 | Reward: 200.15 | MA(50): 109.31
# Ep 1769 | Loss: 1090.45 | Reward: 181.47 | MA(50): 111.50
# Ep 1770 | Loss: 1419.41 | Reward: -47.52 | MA(50): 106.43
# [Track] Last10 Reward Avg: 109.10
# Ep 1771 | Loss: 3176.22 | Reward: 219.88 | MA(50): 111.46
# Ep 1772 | Loss: 3430.69 | Reward: 34.76 | MA(50): 108.18
# Ep 1773 | Loss: 2660.71 | Reward: 164.67 | MA(50): 112.58
# Ep 1774 | Loss: 1964.61 | Reward: 222.50 | MA(50): 118.18
# Ep 1775 | Loss: 3552.43 | Reward: 193.47 | MA(50): 121.87
# Ep 1776 | Loss: 1961.86 | Reward: 106.88 | MA(50): 121.85
# Ep 1777 | Loss: 2111.75 | Reward: 135.85 | MA(50): 122.29
# Ep 1778 | Loss: 2628.65 | Reward: 234.91 | MA(50): 125.27
# Ep 1779 | Loss: 2648.31 | Reward: 127.23 | MA(50): 125.49
# Ep 1780 | Loss: 991.00 | Reward: 197.50 | MA(50): 130.21
# [Track] Last10 Reward Avg: 163.77
# Ep 1781 | Loss: 3387.96 | Reward: 145.10 | MA(50): 129.24
# Ep 1782 | Loss: 3533.79 | Reward: 2.64 | MA(50): 127.31
# Ep 1783 | Loss: 3349.45 | Reward: 64.80 | MA(50): 125.98
# Ep 1784 | Loss: 2656.10 | Reward: -14.19 | MA(50): 124.45
# Ep 1785 | Loss: 2528.70 | Reward: 102.92 | MA(50): 123.89
# Ep 1786 | Loss: 3443.09 | Reward: 197.61 | MA(50): 124.50
# Ep 1787 | Loss: 2868.58 | Reward: 94.75 | MA(50): 123.47
# Ep 1788 | Loss: 3938.25 | Reward: 142.77 | MA(50): 122.87
# Ep 1789 | Loss: 747.60 | Reward: 102.50 | MA(50): 123.56
# Ep 1790 | Loss: 1552.21 | Reward: 161.37 | MA(50): 124.62
# [Track] Last10 Reward Avg: 100.03
# Ep 1791 | Loss: 3589.41 | Reward: 117.96 | MA(50): 127.42
# Ep 1792 | Loss: 4232.51 | Reward: 181.87 | MA(50): 129.45
# Ep 1793 | Loss: 4314.21 | Reward: 142.93 | MA(50): 128.12
# Ep 1794 | Loss: 2924.84 | Reward: 247.68 | MA(50): 131.51
# Ep 1795 | Loss: 2953.14 | Reward: 125.84 | MA(50): 129.86
# Ep 1796 | Loss: 2745.68 | Reward: 132.44 | MA(50): 129.91
# Ep 1797 | Loss: 4284.20 | Reward: 97.68 | MA(50): 129.27
# Ep 1798 | Loss: 3807.86 | Reward: 164.16 | MA(50): 130.33
# Ep 1799 | Loss: 3099.89 | Reward: 150.09 | MA(50): 129.89
# Ep 1800 | Loss: 1944.73 | Reward: 171.39 | MA(50): 130.92
# [Track] Last10 Reward Avg: 153.20
# [Eval] Avg Reward over 5 episodes: 226.29
# Ep 1801 | Loss: 4121.95 | Reward: 97.01 | MA(50): 130.72
# Ep 1802 | Loss: 1679.69 | Reward: 234.61 | MA(50): 136.12
# Ep 1803 | Loss: 4256.95 | Reward: 155.07 | MA(50): 135.92
# Ep 1804 | Loss: 3510.08 | Reward: 118.71 | MA(50): 134.49
# Ep 1805 | Loss: 2304.32 | Reward: 164.02 | MA(50): 133.03
# Ep 1806 | Loss: 2021.70 | Reward: 133.07 | MA(50): 134.18
# Ep 1807 | Loss: 2698.18 | Reward: 137.18 | MA(50): 133.37
# Ep 1808 | Loss: 3112.77 | Reward: 110.86 | MA(50): 133.55
# Ep 1809 | Loss: 1701.30 | Reward: 137.74 | MA(50): 132.95
# Ep 1810 | Loss: 2484.95 | Reward: 128.39 | MA(50): 133.55
# [Track] Last10 Reward Avg: 141.66
# Ep 1811 | Loss: 3116.71 | Reward: 157.75 | MA(50): 134.32
# Ep 1812 | Loss: 1631.76 | Reward: 169.66 | MA(50): 136.42
# Ep 1813 | Loss: 2090.49 | Reward: 137.27 | MA(50): 136.96
# Ep 1814 | Loss: 3450.38 | Reward: 173.20 | MA(50): 139.49
# Ep 1815 | Loss: 4172.69 | Reward: 102.59 | MA(50): 138.14
# Ep 1816 | Loss: 2905.39 | Reward: 168.50 | MA(50): 138.86
# Ep 1817 | Loss: 3007.29 | Reward: 127.13 | MA(50): 139.14
# Ep 1818 | Loss: 3279.77 | Reward: 101.65 | MA(50): 137.17
# Ep 1819 | Loss: 2929.91 | Reward: -29.26 | MA(50): 132.95
# Ep 1820 | Loss: 3242.99 | Reward: 171.62 | MA(50): 137.33
# [Track] Last10 Reward Avg: 128.01
# Ep 1821 | Loss: 2613.63 | Reward: 161.54 | MA(50): 136.17
# Ep 1822 | Loss: 2307.56 | Reward: 215.99 | MA(50): 139.79
# Ep 1823 | Loss: 2177.17 | Reward: 154.29 | MA(50): 139.58
# Ep 1824 | Loss: 3214.46 | Reward: 171.84 | MA(50): 138.57
# Ep 1825 | Loss: 2112.22 | Reward: 130.09 | MA(50): 137.30
# Ep 1826 | Loss: 1666.80 | Reward: 112.21 | MA(50): 137.41
# Ep 1827 | Loss: 2319.13 | Reward: 239.48 | MA(50): 139.48
# Ep 1828 | Loss: 2785.32 | Reward: 109.78 | MA(50): 136.98
# Ep 1829 | Loss: 2155.04 | Reward: 188.14 | MA(50): 138.20
# Ep 1830 | Loss: 2141.46 | Reward: 237.74 | MA(50): 139.00
# [Track] Last10 Reward Avg: 172.11
# Ep 1831 | Loss: 2299.68 | Reward: 166.60 | MA(50): 139.43
# Ep 1832 | Loss: 2654.15 | Reward: 133.14 | MA(50): 142.04
# Ep 1833 | Loss: 3233.19 | Reward: -27.67 | MA(50): 140.19
# Ep 1834 | Loss: 3460.77 | Reward: 161.36 | MA(50): 143.71
# Ep 1835 | Loss: 2107.99 | Reward: -24.19 | MA(50): 141.16
# Ep 1836 | Loss: 2894.19 | Reward: 88.52 | MA(50): 138.98
# Ep 1837 | Loss: 2138.38 | Reward: 122.28 | MA(50): 139.53
# Ep 1838 | Loss: 686.39 | Reward: 168.25 | MA(50): 140.04
# Ep 1839 | Loss: 3050.00 | Reward: 106.12 | MA(50): 140.11
# Ep 1840 | Loss: 2891.06 | Reward: 148.87 | MA(50): 139.86
# [Track] Last10 Reward Avg: 104.33
# Ep 1841 | Loss: 2230.05 | Reward: 164.88 | MA(50): 140.80
# Ep 1842 | Loss: 4335.78 | Reward: 93.37 | MA(50): 139.03
# Ep 1843 | Loss: 3283.95 | Reward: 57.89 | MA(50): 137.33
# Ep 1844 | Loss: 1973.60 | Reward: 126.50 | MA(50): 134.91
# Ep 1845 | Loss: 2674.23 | Reward: 140.01 | MA(50): 135.19
# Ep 1846 | Loss: 2850.62 | Reward: 170.83 | MA(50): 135.96
# Ep 1847 | Loss: 3129.45 | Reward: 99.08 | MA(50): 135.99
# Ep 1848 | Loss: 1696.37 | Reward: 115.80 | MA(50): 135.02
# Ep 1849 | Loss: 4077.34 | Reward: 131.70 | MA(50): 134.65
# Ep 1850 | Loss: 1442.75 | Reward: 96.39 | MA(50): 133.15
# [Track] Last10 Reward Avg: 119.64
# [Eval] Avg Reward over 5 episodes: 87.40
# Ep 1851 | Loss: 2332.56 | Reward: 60.88 | MA(50): 132.43
# Ep 1852 | Loss: 3989.12 | Reward: 59.24 | MA(50): 128.92
# Ep 1853 | Loss: 1160.06 | Reward: 69.94 | MA(50): 127.22
# Ep 1854 | Loss: 3946.61 | Reward: 24.44 | MA(50): 125.33
# Ep 1855 | Loss: 1219.79 | Reward: 243.35 | MA(50): 126.92
# Ep 1856 | Loss: 1838.43 | Reward: 75.12 | MA(50): 125.76
# Ep 1857 | Loss: 2355.57 | Reward: 108.65 | MA(50): 125.19
# Ep 1858 | Loss: 2311.00 | Reward: 116.25 | MA(50): 125.30
# Ep 1859 | Loss: 3739.16 | Reward: 59.69 | MA(50): 123.74
# Ep 1860 | Loss: 3140.28 | Reward: 77.17 | MA(50): 122.71
# [Track] Last10 Reward Avg: 89.47
# Ep 1861 | Loss: 1558.61 | Reward: 230.69 | MA(50): 124.17
# Ep 1862 | Loss: 1557.19 | Reward: 180.79 | MA(50): 124.40
# Ep 1863 | Loss: 1924.24 | Reward: 219.59 | MA(50): 126.04
# Ep 1864 | Loss: 3334.26 | Reward: 196.30 | MA(50): 126.50
# Ep 1865 | Loss: 2206.89 | Reward: 244.31 | MA(50): 129.34
# Ep 1866 | Loss: 4027.67 | Reward: 111.06 | MA(50): 128.19
# Ep 1867 | Loss: 2244.60 | Reward: 156.27 | MA(50): 128.77
# Ep 1868 | Loss: 1536.91 | Reward: 261.76 | MA(50): 131.97
# Ep 1869 | Loss: 3746.84 | Reward: 89.13 | MA(50): 134.34
# Ep 1870 | Loss: 3218.01 | Reward: 105.92 | MA(50): 133.03
# [Track] Last10 Reward Avg: 179.58
# Ep 1871 | Loss: 3129.67 | Reward: 135.10 | MA(50): 132.50
# Ep 1872 | Loss: 3301.48 | Reward: 94.98 | MA(50): 130.08
# Ep 1873 | Loss: 2598.54 | Reward: 129.16 | MA(50): 129.58
# Ep 1874 | Loss: 2895.21 | Reward: 144.59 | MA(50): 129.03
# Ep 1875 | Loss: 2844.14 | Reward: 121.60 | MA(50): 128.86
# Ep 1876 | Loss: 3918.13 | Reward: 97.26 | MA(50): 128.56
# Ep 1877 | Loss: 3437.80 | Reward: 154.78 | MA(50): 126.87
# Ep 1878 | Loss: 2164.39 | Reward: 138.10 | MA(50): 127.43
# Ep 1879 | Loss: 1782.54 | Reward: 133.83 | MA(50): 126.35
# Ep 1880 | Loss: 2673.35 | Reward: 136.10 | MA(50): 124.32
# [Track] Last10 Reward Avg: 128.55
# Ep 1881 | Loss: 2326.19 | Reward: 117.73 | MA(50): 123.34
# Ep 1882 | Loss: 4180.62 | Reward: 98.25 | MA(50): 122.64
# Ep 1883 | Loss: 1045.96 | Reward: 159.56 | MA(50): 126.39
# Ep 1884 | Loss: 2644.64 | Reward: 93.63 | MA(50): 125.03
# Ep 1885 | Loss: 2696.89 | Reward: 121.79 | MA(50): 127.95
# Ep 1886 | Loss: 2557.26 | Reward: 150.13 | MA(50): 129.18
# Ep 1887 | Loss: 4218.22 | Reward: 149.87 | MA(50): 129.73
# Ep 1888 | Loss: 2797.90 | Reward: 279.59 | MA(50): 131.96
# Ep 1889 | Loss: 3477.17 | Reward: 148.56 | MA(50): 132.81
# Ep 1890 | Loss: 4059.82 | Reward: 107.83 | MA(50): 131.99
# [Track] Last10 Reward Avg: 142.69
# Ep 1891 | Loss: 3563.11 | Reward: 144.64 | MA(50): 131.58
# Ep 1892 | Loss: 2837.73 | Reward: 139.08 | MA(50): 132.50
# Ep 1893 | Loss: 2223.07 | Reward: 92.30 | MA(50): 133.19
# Ep 1894 | Loss: 1782.68 | Reward: 128.19 | MA(50): 133.22
# Ep 1895 | Loss: 2579.63 | Reward: 97.23 | MA(50): 132.36
# Ep 1896 | Loss: 2840.76 | Reward: 113.10 | MA(50): 131.21
# Ep 1897 | Loss: 5350.11 | Reward: 154.99 | MA(50): 132.33
# Ep 1898 | Loss: 4083.85 | Reward: -23.23 | MA(50): 129.55
# Ep 1899 | Loss: 3955.51 | Reward: 162.04 | MA(50): 130.15
# Ep 1900 | Loss: 1710.80 | Reward: 174.09 | MA(50): 131.71
# [Track] Last10 Reward Avg: 118.24
# [Eval] Avg Reward over 5 episodes: 210.15
# Ep 1901 | Loss: 1409.38 | Reward: 138.23 | MA(50): 133.26
# Ep 1902 | Loss: 1921.11 | Reward: -32.43 | MA(50): 131.42
# Ep 1903 | Loss: 3801.72 | Reward: 128.36 | MA(50): 132.59
# Ep 1904 | Loss: 3253.73 | Reward: 175.15 | MA(50): 135.60
# Ep 1905 | Loss: 1743.01 | Reward: 191.27 | MA(50): 134.56
# Ep 1906 | Loss: 1505.36 | Reward: 106.91 | MA(50): 135.20
# Ep 1907 | Loss: 2558.09 | Reward: -22.28 | MA(50): 132.58
# Ep 1908 | Loss: 3045.46 | Reward: 225.70 | MA(50): 134.77
# Ep 1909 | Loss: 2052.63 | Reward: 281.22 | MA(50): 139.20
# Ep 1910 | Loss: 3077.68 | Reward: -15.40 | MA(50): 137.35
# [Track] Last10 Reward Avg: 117.67
# Ep 1911 | Loss: 3056.34 | Reward: 283.13 | MA(50): 138.40
# Ep 1912 | Loss: 1082.52 | Reward: -46.36 | MA(50): 133.85
# Ep 1913 | Loss: 1766.45 | Reward: 291.71 | MA(50): 135.30
# Ep 1914 | Loss: 2469.89 | Reward: -17.97 | MA(50): 131.01
# Ep 1915 | Loss: 3578.57 | Reward: 131.80 | MA(50): 128.76
# Ep 1916 | Loss: 2919.39 | Reward: 235.88 | MA(50): 131.26
# Ep 1917 | Loss: 1735.08 | Reward: -6.11 | MA(50): 128.01
# Ep 1918 | Loss: 1116.30 | Reward: 227.09 | MA(50): 127.32
# Ep 1919 | Loss: 1156.08 | Reward: 221.05 | MA(50): 129.95
# Ep 1920 | Loss: 1887.28 | Reward: 245.75 | MA(50): 132.75
# [Track] Last10 Reward Avg: 156.60
# Ep 1921 | Loss: 1965.38 | Reward: 11.06 | MA(50): 130.27
# Ep 1922 | Loss: 2309.79 | Reward: 142.54 | MA(50): 131.22
# Ep 1923 | Loss: 4318.10 | Reward: 264.49 | MA(50): 133.93
# Ep 1924 | Loss: 2689.33 | Reward: 213.10 | MA(50): 135.30
# Ep 1925 | Loss: 2214.65 | Reward: 242.08 | MA(50): 137.71
# Ep 1926 | Loss: 3047.76 | Reward: 233.73 | MA(50): 140.44
# Ep 1927 | Loss: 1909.73 | Reward: 236.88 | MA(50): 142.08
# Ep 1928 | Loss: 3118.87 | Reward: 231.95 | MA(50): 143.96
# Ep 1929 | Loss: 2692.64 | Reward: -32.19 | MA(50): 140.64
# Ep 1930 | Loss: 2269.37 | Reward: 235.37 | MA(50): 142.62
# [Track] Last10 Reward Avg: 177.90
# Ep 1931 | Loss: 2532.28 | Reward: 13.99 | MA(50): 140.55
# Ep 1932 | Loss: 3336.37 | Reward: -3.43 | MA(50): 138.51
# Ep 1933 | Loss: 2846.06 | Reward: 250.58 | MA(50): 140.33
# Ep 1934 | Loss: 1645.03 | Reward: 226.56 | MA(50): 142.99
# Ep 1935 | Loss: 1463.34 | Reward: 259.22 | MA(50): 145.74
# Ep 1936 | Loss: 2628.09 | Reward: 244.19 | MA(50): 147.62
# Ep 1937 | Loss: 2563.36 | Reward: 232.10 | MA(50): 149.27
# Ep 1938 | Loss: 2333.04 | Reward: 245.32 | MA(50): 148.58
# Ep 1939 | Loss: 3144.71 | Reward: 266.29 | MA(50): 150.94
# Ep 1940 | Loss: 2643.65 | Reward: 4.10 | MA(50): 148.86
# [Track] Last10 Reward Avg: 173.89
# Ep 1941 | Loss: 3112.55 | Reward: 243.66 | MA(50): 150.84
# Ep 1942 | Loss: 3978.35 | Reward: -56.33 | MA(50): 146.93
# Ep 1943 | Loss: 2864.32 | Reward: 261.17 | MA(50): 150.31
# Ep 1944 | Loss: 1876.69 | Reward: 194.76 | MA(50): 151.64
# Ep 1945 | Loss: 1177.88 | Reward: 242.65 | MA(50): 154.55
# Ep 1946 | Loss: 2231.74 | Reward: -10.18 | MA(50): 152.08
# Ep 1947 | Loss: 2012.63 | Reward: -39.55 | MA(50): 148.19
# Ep 1948 | Loss: 3414.44 | Reward: 288.92 | MA(50): 154.44
# Ep 1949 | Loss: 2625.44 | Reward: -84.97 | MA(50): 149.50
# Ep 1950 | Loss: 2617.46 | Reward: -13.97 | MA(50): 145.74
# [Track] Last10 Reward Avg: 102.62
# [Eval] Avg Reward over 5 episodes: 159.50
# Ep 1951 | Loss: 2504.38 | Reward: 59.50 | MA(50): 144.16
# Ep 1952 | Loss: 3519.16 | Reward: 188.45 | MA(50): 148.58
# Ep 1953 | Loss: 3497.78 | Reward: 256.03 | MA(50): 151.13
# Ep 1954 | Loss: 4423.45 | Reward: -7.24 | MA(50): 147.48
# Ep 1955 | Loss: 2771.16 | Reward: 250.38 | MA(50): 148.67
# Ep 1956 | Loss: 3453.06 | Reward: -11.61 | MA(50): 146.30
# Ep 1957 | Loss: 4326.48 | Reward: -37.58 | MA(50): 145.99
# Ep 1958 | Loss: 3974.61 | Reward: 224.70 | MA(50): 145.97
# Ep 1959 | Loss: 1625.05 | Reward: -0.22 | MA(50): 140.34
# Ep 1960 | Loss: 2602.99 | Reward: 206.19 | MA(50): 144.77
# [Track] Last10 Reward Avg: 112.86
# Ep 1961 | Loss: 2358.94 | Reward: -17.63 | MA(50): 138.76
# Ep 1962 | Loss: 3303.92 | Reward: 128.40 | MA(50): 142.25
# Ep 1963 | Loss: 2647.48 | Reward: -11.60 | MA(50): 136.19
# Ep 1964 | Loss: 638.74 | Reward: 264.49 | MA(50): 141.84
# Ep 1965 | Loss: 2246.44 | Reward: 260.58 | MA(50): 144.41
# Ep 1966 | Loss: 3265.49 | Reward: -21.93 | MA(50): 139.26
# Ep 1967 | Loss: 2866.55 | Reward: 4.65 | MA(50): 139.47
# Ep 1968 | Loss: 2609.00 | Reward: -18.62 | MA(50): 134.56
# Ep 1969 | Loss: 2476.46 | Reward: 257.91 | MA(50): 135.29
# Ep 1970 | Loss: 1681.74 | Reward: 188.31 | MA(50): 134.14
# [Track] Last10 Reward Avg: 103.46
# Ep 1971 | Loss: 2814.93 | Reward: -32.28 | MA(50): 133.28
# Ep 1972 | Loss: 2661.00 | Reward: 286.16 | MA(50): 136.15
# Ep 1973 | Loss: 3269.99 | Reward: 105.46 | MA(50): 132.97
# Ep 1974 | Loss: 3874.23 | Reward: -15.10 | MA(50): 128.41
# Ep 1975 | Loss: 2261.54 | Reward: -104.93 | MA(50): 121.47
# Ep 1976 | Loss: 2165.87 | Reward: 181.59 | MA(50): 120.42
# Ep 1977 | Loss: 2880.93 | Reward: 90.00 | MA(50): 117.49
# Ep 1978 | Loss: 2838.72 | Reward: 179.07 | MA(50): 116.43
# Ep 1979 | Loss: 2421.33 | Reward: 148.34 | MA(50): 120.04
# Ep 1980 | Loss: 2301.86 | Reward: 284.17 | MA(50): 121.01
# [Track] Last10 Reward Avg: 112.25
# Ep 1981 | Loss: 3079.28 | Reward: -34.71 | MA(50): 120.04
# Ep 1982 | Loss: 4737.14 | Reward: 198.86 | MA(50): 124.09
# Ep 1983 | Loss: 2652.23 | Reward: 185.18 | MA(50): 122.78
# Ep 1984 | Loss: 3788.93 | Reward: 272.65 | MA(50): 123.70
# Ep 1985 | Loss: 922.32 | Reward: 15.48 | MA(50): 118.82
# Ep 1986 | Loss: 1524.44 | Reward: 156.17 | MA(50): 117.06
# Ep 1987 | Loss: 3705.13 | Reward: 190.11 | MA(50): 116.22
# Ep 1988 | Loss: 4298.03 | Reward: -35.66 | MA(50): 110.61
# Ep 1989 | Loss: 3560.62 | Reward: -37.00 | MA(50): 104.54
# Ep 1990 | Loss: 2411.92 | Reward: 26.37 | MA(50): 104.99
# [Track] Last10 Reward Avg: 93.75
# Ep 1991 | Loss: 3255.54 | Reward: 246.80 | MA(50): 105.05
# Ep 1992 | Loss: 2636.41 | Reward: 268.45 | MA(50): 111.54
# Ep 1993 | Loss: 4100.55 | Reward: -49.79 | MA(50): 105.32
# Ep 1994 | Loss: 3323.74 | Reward: 272.62 | MA(50): 106.88
# Ep 1995 | Loss: 2601.44 | Reward: 239.12 | MA(50): 106.81
# Ep 1996 | Loss: 3142.74 | Reward: 254.04 | MA(50): 112.10
# Ep 1997 | Loss: 1973.39 | Reward: 3.06 | MA(50): 112.95
# Ep 1998 | Loss: 3716.00 | Reward: 245.16 | MA(50): 112.07
# Ep 1999 | Loss: 2939.09 | Reward: 9.39 | MA(50): 113.96
# ✅ Models saved as 'pcl_policy_lunarlander.pt' and 'pcl_value_lunarlander.pt'
# 🎉 Problem Solved: Agent consistently lands the Lunar Lander!
# ✅ GIF saved as 'D:/Coding Projects/Reinforcement Learning/lander_demo_final.gif'
# 📈 Training plot saved as 'training_metrics.png'

# %%
from IPython.display import Image

# Provide the path to your GIF file
file_path = r'D:\Coding Projects\Reinforcement Learning\lander_demo_final.gif'

# Display the GIF
Image(filename=file_path)

# %% [markdown]
# OPTIMIZED VERSION:

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import gymnasium as gym
import numpy as np
import random
from collections import deque
import matplotlib.pyplot as plt
import imageio
import os

# Hyperparameters
ENV_NAME = "LunarLander-v3"

EPISODES = 2000
GAMMA = 0.99
TAU = 0.05  # reduced entropy weight
K = 2
LR = 3e-4


MAX_STEPS = 500
REPLAY_SIZE = 10000
BATCH_SIZE = 64
EVAL_INTERVAL = 50
GRAD_CLIP = 1.0
GIF_SAVE_PATH = "D:/Coding Projects/Reinforcement Learning/lander_demo_final_optimized_2.gif"

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class PolicyNet(nn.Module):
    def __init__(self, state_dim, action_dim):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(state_dim, 128), nn.ReLU(),
            nn.Linear(128, 128), nn.ReLU(),
            nn.Linear(128, action_dim)
        )

    def forward(self, x):
        logits = self.model(x)
        log_probs = F.log_softmax(logits, dim=-1)
        probs = F.softmax(logits, dim=-1)
        return log_probs, probs

class ValueNet(nn.Module):
    def __init__(self, state_dim):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(state_dim, 128), nn.ReLU(),
            nn.Linear(128, 128), nn.ReLU(),
            nn.Linear(128, 1)
        )

    def forward(self, x):
        return self.model(x).squeeze(-1)

class TrajectoryReplayBuffer:
    def __init__(self, max_size):
        self.buffer = deque(maxlen=max_size)

    def push(self, trajectory):
        total_reward = sum([step[2] for step in trajectory])
        if total_reward > 0 or random.random() < 0.3:  # filter failed episodes
            self.buffer.append(trajectory)

    def sample(self, batch_size, k):
        samples = []
        for _ in range(batch_size):
            traj = random.choice(self.buffer)
            if len(traj) > k:
                t = random.randint(0, len(traj) - k - 1)
                samples.append(traj[t:t + k + 1])
        return samples

    def __len__(self):
        return len(self.buffer)

def collect_trajectory(env, policy_net):
    traj = []
    obs, _ = env.reset()
    for _ in range(MAX_STEPS):
        obs_tensor = torch.FloatTensor(obs).unsqueeze(0).to(device)
        log_probs, probs = policy_net(obs_tensor)
        dist = torch.distributions.Categorical(probs)
        action = dist.sample().item()

        next_obs, reward, terminated, truncated, _ = env.step(action)

        # reward shaping
        if next_obs[1] > obs[1]:  # moved up
            reward += 0.05
        if abs(next_obs[4]) < 0.1:  # small angle tilt
            reward += 0.1

        traj.append((obs, action, reward, next_obs))

        if terminated or truncated:
            break
        obs = next_obs
    return traj

def evaluate_policy(env, policy_net, episodes=5):
    policy_net.eval()
    total_reward = 0
    for _ in range(episodes):
        obs, _ = env.reset()
        done = False
        episode_reward = 0
        while not done:
            obs_tensor = torch.FloatTensor(obs).unsqueeze(0).to(device)
            _, probs = policy_net(obs_tensor)
            action = torch.argmax(probs, dim=1).item()
            obs, reward, terminated, truncated, _ = env.step(action)
            episode_reward += reward
            done = terminated or truncated
        total_reward += episode_reward
    avg_reward = total_reward / episodes
    print(f"[Eval] Avg Reward over {episodes} episodes: {avg_reward:.2f}")
    policy_net.train()

def generate_gif(policy_net):
    env = gym.make(ENV_NAME, render_mode="rgb_array")
    obs, _ = env.reset()
    frames = []
    for _ in range(MAX_STEPS):
        frame = env.render()
        frames.append(frame)
        obs_tensor = torch.FloatTensor(obs).unsqueeze(0).to(device)
        with torch.no_grad():
            _, probs = policy_net(obs_tensor)
        action = torch.argmax(probs, dim=1).item()
        obs, _, terminated, truncated, _ = env.step(action)
        if terminated or truncated:
            break
    env.close()
    imageio.mimsave(GIF_SAVE_PATH, frames, duration=1/30)
    print(f"✅ GIF saved as '{GIF_SAVE_PATH}'")

def plot_metrics(reward_history, loss_history):
    min_len = min(len(reward_history), len(loss_history))
    reward_history = reward_history[:min_len]
    loss_history = loss_history[:min_len]
    episodes = np.arange(min_len)

    plt.figure(figsize=(12, 5))
    
    # Reward Plot
    plt.subplot(1, 2, 1)
    plt.plot(episodes, reward_history, label="Reward")
    if len(reward_history) >= 50:
        ma50 = np.convolve(reward_history, np.ones(50)/50, mode='valid')
        plt.plot(np.arange(49, len(ma50)+49), ma50, label="MA(50)")
    plt.axhline(200, color="gray", linestyle="--", label="Solve Threshold")
    plt.xlabel("Episode")
    plt.ylabel("Reward")
    plt.legend()
    plt.title("Episode Rewards")

    # Loss Plot
    plt.subplot(1, 2, 2)
    plt.plot(episodes, loss_history, label="Loss")
    plt.xlabel("Episode")
    plt.ylabel("Loss")
    plt.title("Loss Curve")
    plt.legend()

    plt.tight_layout()
    plt.savefig("training_metrics.png")
    print("📈 Training plot saved as 'training_metrics.png'")
    plt.show()


def train():
    env = gym.make(ENV_NAME)
    state_dim = env.observation_space.shape[0]
    action_dim = env.action_space.n

    policy_net = PolicyNet(state_dim, action_dim).to(device)
    value_net = ValueNet(state_dim).to(device)

    optimizer = optim.AdamW(list(policy_net.parameters()) + list(value_net.parameters()), lr=LR, weight_decay=1e-4)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.97)
    buffer = TrajectoryReplayBuffer(REPLAY_SIZE)
    reward_history = []
    loss_history = []

    for episode in range(EPISODES):
        ## Compute recent moving average reward
        if len(reward_history) == 0:
            avg_reward = 0
        else:
            avg_reward = sum(reward_history[-50:]) / min(len(reward_history), 50)

        # Dynamic entropy decay + performance-aware override
        if avg_reward > 150:
            entropy_coeff = 0.001  # reduce exploration aggressively
        elif episode < 500:
            entropy_coeff = max(0.01, TAU * (0.99 ** episode))
        else:
            entropy_coeff = 0.01

        traj = collect_trajectory(env, policy_net)
        buffer.push(traj)
        episode_reward = sum([step[2] for step in traj])
        reward_history.append(episode_reward)

        if len(buffer) < BATCH_SIZE:
            continue

        batch = buffer.sample(BATCH_SIZE, K)
        total_loss = 0

        for path in batch:
            R, log_pi_sum = 0, 0
            for i in range(K):
                s_i, a_i, r_i, _ = path[i]
                R += (GAMMA ** i) * r_i
                s_i_tensor = torch.FloatTensor(s_i).unsqueeze(0).to(device)
                log_probs, _ = policy_net(s_i_tensor)
                clipped_log_prob = torch.clamp(log_probs[0, a_i], min=-20, max=0)
                log_pi_sum += clipped_log_prob

            s_t = torch.FloatTensor(path[0][0]).unsqueeze(0).to(device)
            s_tk = torch.FloatTensor(path[K][0]).unsqueeze(0).to(device)
            V_s_t = value_net(s_t)
            V_s_tk = torch.clamp(value_net(s_tk).detach(), min=-500, max=500)

            delta = R + (GAMMA ** K) * V_s_tk - V_s_t - entropy_coeff * log_pi_sum
            delta = torch.clamp(delta, min=-20, max=20)
            loss = delta.pow(2).mean()

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(list(policy_net.parameters()) + list(value_net.parameters()), GRAD_CLIP)
            optimizer.step()
            total_loss += loss.item()

        loss_history.append(total_loss)
        scheduler.step()
        print(f"Ep {episode:03d} | Loss: {total_loss:.2f} | Reward: {episode_reward:.2f} | MA(50): {avg_reward:.2f}")

        if episode % 10 == 0:
            print(f"[Track] Last10 Reward Avg: {np.mean(reward_history[-10:]):.2f}")
        if episode % EVAL_INTERVAL == 0:
            evaluate_policy(env, policy_net)

         # ✅ EARLY STOPPING CHECK
        avg_reward_check = np.mean(reward_history[-10:])
        if avg_reward_check >= 180:
            print(f"🎉 Converged at Episode {episode} with Last10 Avg: {avg_reward_check:.2f} — stopping early.")
            break


    torch.save(policy_net.state_dict(), "pcl_policy_lunarlander.pt")
    torch.save(value_net.state_dict(), "pcl_value_lunarlander.pt")
    print("✅ Models saved as 'pcl_policy_lunarlander.pt' and 'pcl_value_lunarlander.pt'")
    env.close()

    if any(np.mean(reward_history[i:i+10]) > 200 for i in range(len(reward_history) - 10)):
        print("🎉 Problem Solved: Agent consistently lands the Lunar Lander!")
    else:
        print("⚠️ Not yet solved: Keep training or tune hyperparameters.")

    generate_gif(policy_net)
    plot_metrics(reward_history, loss_history)

if __name__ == "__main__":
    train()
# Out:
# Ep 233 | Loss: 1265.26 | Reward: -49.97 | MA(50): -190.40
# Ep 234 | Loss: 1590.03 | Reward: -112.94 | MA(50): -183.06
# Ep 235 | Loss: 1217.65 | Reward: -386.78 | MA(50): -184.96
# Ep 236 | Loss: 839.04 | Reward: -292.36 | MA(50): -187.22
# Ep 237 | Loss: 1502.62 | Reward: -566.74 | MA(50): -187.04
# Ep 238 | Loss: 1968.02 | Reward: -917.12 | MA(50): -196.92
# Ep 239 | Loss: 1685.60 | Reward: -606.41 | MA(50): -213.46
# Ep 240 | Loss: 966.93 | Reward: -730.38 | MA(50): -222.83
# [Track] Last10 Reward Avg: -404.34
# Ep 241 | Loss: 1278.18 | Reward: -566.48 | MA(50): -235.86
# Ep 242 | Loss: 1153.94 | Reward: -584.14 | MA(50): -240.73
# Ep 243 | Loss: 1757.12 | Reward: -702.00 | MA(50): -250.94
# Ep 244 | Loss: 1802.67 | Reward: -611.09 | MA(50): -262.67
# Ep 245 | Loss: 975.84 | Reward: -488.57 | MA(50): -273.00
# Ep 246 | Loss: 1218.34 | Reward: -383.67 | MA(50): -281.13
# Ep 247 | Loss: 1221.78 | Reward: -569.82 | MA(50): -288.77
# Ep 248 | Loss: 1410.18 | Reward: -819.06 | MA(50): -294.02
# Ep 249 | Loss: 2108.68 | Reward: -523.75 | MA(50): -309.10
# Ep 250 | Loss: 1661.34 | Reward: -488.49 | MA(50): -315.98
# [Track] Last10 Reward Avg: -573.71
# [Eval] Avg Reward over 5 episodes: -523.11
# Ep 251 | Loss: 2255.20 | Reward: -1748.20 | MA(50): -319.47
# Ep 252 | Loss: 1804.58 | Reward: -405.65 | MA(50): -347.72
# Ep 253 | Loss: 1975.39 | Reward: -598.31 | MA(50): -353.45
# Ep 254 | Loss: 3094.42 | Reward: -764.84 | MA(50): -361.48
# Ep 255 | Loss: 1067.50 | Reward: -562.05 | MA(50): -374.67
# Ep 256 | Loss: 1987.49 | Reward: -942.49 | MA(50): -383.82
# Ep 257 | Loss: 1598.04 | Reward: -1320.22 | MA(50): -399.42
# Ep 258 | Loss: 786.39 | Reward: -3053.81 | MA(50): -423.64
# Ep 259 | Loss: 1777.26 | Reward: -470.83 | MA(50): -481.81
# Ep 260 | Loss: 1549.84 | Reward: -601.36 | MA(50): -490.19
# [Track] Last10 Reward Avg: -1046.78
# Ep 261 | Loss: 2744.99 | Reward: -1250.38 | MA(50): -500.18
# Ep 262 | Loss: 1332.14 | Reward: -1118.74 | MA(50): -520.34
# Ep 263 | Loss: 2251.84 | Reward: -592.42 | MA(50): -535.15
# Ep 264 | Loss: 2419.25 | Reward: -544.78 | MA(50): -542.84
# Ep 265 | Loss: 2710.22 | Reward: -389.55 | MA(50): -547.35
# Ep 266 | Loss: 1812.32 | Reward: -368.85 | MA(50): -551.54
# Ep 267 | Loss: 1829.95 | Reward: -597.11 | MA(50): -557.12
# Ep 268 | Loss: 1085.14 | Reward: -1973.80 | MA(50): -567.39
# Ep 269 | Loss: 2558.21 | Reward: -503.49 | MA(50): -600.22
# Ep 270 | Loss: 3709.83 | Reward: -887.75 | MA(50): -602.99
# [Track] Last10 Reward Avg: -822.69
# Ep 271 | Loss: 2861.80 | Reward: -533.86 | MA(50): -618.10
# Ep 272 | Loss: 2637.51 | Reward: -461.74 | MA(50): -626.76
# Ep 273 | Loss: 1568.47 | Reward: -592.29 | MA(50): -631.62
# Ep 274 | Loss: 2498.72 | Reward: -378.28 | MA(50): -638.82
# Ep 275 | Loss: 1443.94 | Reward: -401.08 | MA(50): -640.29
# Ep 276 | Loss: 1739.07 | Reward: -605.41 | MA(50): -639.06
# Ep 277 | Loss: 2598.63 | Reward: -1715.81 | MA(50): -648.10
# Ep 278 | Loss: 2721.91 | Reward: -745.32 | MA(50): -674.05
# Ep 279 | Loss: 2721.03 | Reward: -442.31 | MA(50): -687.28
# Ep 280 | Loss: 1872.66 | Reward: -479.35 | MA(50): -689.06
# [Track] Last10 Reward Avg: -635.55
# Ep 281 | Loss: 1060.69 | Reward: -3584.26 | MA(50): -696.61
# Ep 282 | Loss: 2001.38 | Reward: -546.38 | MA(50): -764.14
# Ep 283 | Loss: 2440.04 | Reward: -636.06 | MA(50): -771.61
# Ep 284 | Loss: 2140.67 | Reward: -525.26 | MA(50): -783.33
# Ep 285 | Loss: 1989.37 | Reward: -916.52 | MA(50): -791.58
# Ep 286 | Loss: 2386.89 | Reward: -606.36 | MA(50): -802.17
# Ep 287 | Loss: 1694.84 | Reward: -985.30 | MA(50): -808.45
# Ep 288 | Loss: 2075.68 | Reward: -421.04 | MA(50): -816.82
# Ep 289 | Loss: 2325.49 | Reward: -639.47 | MA(50): -806.90
# Ep 290 | Loss: 2851.99 | Reward: -883.80 | MA(50): -807.56
# [Track] Last10 Reward Avg: -974.44
# Ep 291 | Loss: 4261.07 | Reward: -603.09 | MA(50): -810.63
# Ep 292 | Loss: 3097.59 | Reward: -534.62 | MA(50): -811.36
# Ep 293 | Loss: 1669.96 | Reward: -734.74 | MA(50): -810.37
# Ep 294 | Loss: 3283.68 | Reward: -711.66 | MA(50): -811.03
# Ep 295 | Loss: 2584.60 | Reward: -610.50 | MA(50): -813.04
# Ep 296 | Loss: 3116.17 | Reward: -749.80 | MA(50): -815.48
# Ep 297 | Loss: 2629.92 | Reward: -499.08 | MA(50): -822.80
# Ep 298 | Loss: 2690.72 | Reward: -608.12 | MA(50): -821.39
# Ep 299 | Loss: 2565.81 | Reward: -346.02 | MA(50): -817.17
# Ep 300 | Loss: 2073.10 | Reward: -524.12 | MA(50): -813.61
# [Track] Last10 Reward Avg: -592.18
# [Eval] Avg Reward over 5 episodes: -637.30
# Ep 301 | Loss: 3150.57 | Reward: -557.91 | MA(50): -814.33
# Ep 302 | Loss: 2782.37 | Reward: -389.20 | MA(50): -790.52
# Ep 303 | Loss: 4719.75 | Reward: -324.39 | MA(50): -790.19
# Ep 304 | Loss: 3630.11 | Reward: -440.93 | MA(50): -784.71
# Ep 305 | Loss: 3685.06 | Reward: -483.50 | MA(50): -778.23
# Ep 306 | Loss: 2184.34 | Reward: -451.60 | MA(50): -776.66
# Ep 307 | Loss: 5067.43 | Reward: -608.14 | MA(50): -766.85
# Ep 308 | Loss: 2998.69 | Reward: -597.02 | MA(50): -752.60
# Ep 309 | Loss: 3458.70 | Reward: -81.32 | MA(50): -703.47
# Ep 310 | Loss: 3627.77 | Reward: -30.58 | MA(50): -695.68
# [Track] Last10 Reward Avg: -396.46
# Ep 311 | Loss: 3546.93 | Reward: 157.40 | MA(50): -684.26
# Ep 312 | Loss: 3890.25 | Reward: -348.66 | MA(50): -656.11
# Ep 313 | Loss: 4007.43 | Reward: -8.63 | MA(50): -640.71
# Ep 314 | Loss: 1481.63 | Reward: 0.58 | MA(50): -629.03
# Ep 315 | Loss: 2755.53 | Reward: 55.88 | MA(50): -618.12
# Ep 316 | Loss: 4188.00 | Reward: 42.68 | MA(50): -609.21
# Ep 317 | Loss: 3486.04 | Reward: -180.75 | MA(50): -600.98
# Ep 318 | Loss: 3478.46 | Reward: 216.26 | MA(50): -592.66
# Ep 319 | Loss: 2942.43 | Reward: -247.92 | MA(50): -548.85
# Ep 320 | Loss: 3310.84 | Reward: 172.06 | MA(50): -543.74
# [Track] Last10 Reward Avg: -14.11
# Ep 321 | Loss: 3336.73 | Reward: 69.24 | MA(50): -522.55
# Ep 322 | Loss: 3329.53 | Reward: 22.74 | MA(50): -510.48
# Ep 323 | Loss: 3149.16 | Reward: 17.49 | MA(50): -500.79
# Ep 324 | Loss: 3890.25 | Reward: -7.92 | MA(50): -488.60
# Ep 325 | Loss: 2569.15 | Reward: 2.98 | MA(50): -481.19
# Ep 326 | Loss: 2189.93 | Reward: -86.38 | MA(50): -473.11
# Ep 327 | Loss: 3852.98 | Reward: 28.80 | MA(50): -462.73
# Ep 328 | Loss: 3305.16 | Reward: 27.79 | MA(50): -427.84
# Ep 329 | Loss: 3057.56 | Reward: 50.74 | MA(50): -412.38
# Ep 330 | Loss: 3158.64 | Reward: 60.64 | MA(50): -402.51
# [Track] Last10 Reward Avg: 18.61
# Ep 331 | Loss: 4584.93 | Reward: 44.39 | MA(50): -391.71
# Ep 332 | Loss: 2472.82 | Reward: 11.16 | MA(50): -319.14
# Ep 333 | Loss: 3826.55 | Reward: -5.64 | MA(50): -307.99
# Ep 334 | Loss: 2773.42 | Reward: 40.79 | MA(50): -295.38
# Ep 335 | Loss: 3696.27 | Reward: 67.98 | MA(50): -284.06
# Ep 336 | Loss: 4613.38 | Reward: 48.38 | MA(50): -264.37
# Ep 337 | Loss: 4130.46 | Reward: 28.75 | MA(50): -251.28
# Ep 338 | Loss: 4991.45 | Reward: -14.68 | MA(50): -231.00
# Ep 339 | Loss: 3828.83 | Reward: 53.26 | MA(50): -222.87
# Ep 340 | Loss: 3962.90 | Reward: 225.35 | MA(50): -209.01
# [Track] Last10 Reward Avg: 49.97
# Ep 341 | Loss: 4107.55 | Reward: 63.32 | MA(50): -186.83
# Ep 342 | Loss: 4525.36 | Reward: 64.61 | MA(50): -173.50
# Ep 343 | Loss: 3921.91 | Reward: 224.20 | MA(50): -161.52
# Ep 344 | Loss: 5456.60 | Reward: 203.93 | MA(50): -142.34
# Ep 345 | Loss: 3893.85 | Reward: 193.07 | MA(50): -124.03
# Ep 346 | Loss: 3443.07 | Reward: 209.19 | MA(50): -107.96
# Ep 347 | Loss: 6565.81 | Reward: 188.44 | MA(50): -88.78
# Ep 348 | Loss: 3134.21 | Reward: 226.62 | MA(50): -75.03
# Ep 349 | Loss: 3819.75 | Reward: 204.86 | MA(50): -58.33
# 🎉 Converged at Episode 349 with Last10 Avg: 180.36 — stopping early.
# ✅ Models saved as 'pcl_policy_lunarlander.pt' and 'pcl_value_lunarlander.pt'
# ⚠️ Not yet solved: Keep training or tune hyperparameters.
# ✅ GIF saved as 'D:/Coding Projects/Reinforcement Learning/lander_demo_final_optimized_2.gif'
# 📈 Training plot saved as 'training_metrics.png'

# %%
from IPython.display import Image

# Provide the path to your GIF file
file_path = r'D:\Coding Projects\Reinforcement Learning\lander_demo_final_optimized_2.gif'

# Display the GIF
Image(filename=file_path)
